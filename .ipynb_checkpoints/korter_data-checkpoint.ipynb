# %% [markdown]
# #### Korter Data Scrappinig

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (3.141.0)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from selenium) (1.24.2)

# %%
import pandas as pd
import numpy as np

# https://developer.apple.com/documentation/webkit/testing_with_webdriver_in_safari
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver

from bs4 import BeautifulSoup

import requests
import unittest
import time
import datetime

# %%
# driver = webdriver.Safari()
building_name = []
address = []
price = []
developer = []
website = []

x = datetime.datetime.now()

city = str(input("Type the name of the city: "))
# city = "Bucuresti"
url = "https://korter.ro/ansambluri-rezidentiale-in-" + city
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
check = soup.find(class_="ListingHeader__StyledComment-sc-6vo33j-2")
# print(check.prettify())
[type(item) for item in list(check.children)]
number = list(check.children)[2]
number = int(number) 
number = number / 20
number_pages = int(number) + 2

# for pg in range(1, number):
for pg in range(1, number_pages):
    page_num = str(pg)
    url = "https://korter.ro/ansambluri-rezidentiale-in-" + city + "?page=" + page_num
    # page = driver.get(url)
    # soup = BeautifulSoup(driver.page_source, 'html.parser')
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    # print(soup.prettify())
    
    # buildinigs_stream = soup.find(class_="BuildingsStream__StyledCardsWrapper-sc-1umumy-1 kuhGjm")
    buildinigs_stream = soup.find(class_="BuildingsStream__StyledCardsWrapper-sc-1umumy-1")
    # buildinigs_stream = soup.find(class_="BuildingsStream__StyledWrapper-sc-1umumy-0")
    # print(buildinigs_stream.prettify())
    
    building_name_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingName-sc-1t8cw05-5")
    building_name_e = [bnt.get_text() for bnt in building_name_tags]
    building_name.extend(building_name_e)
    
    address_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingLocation-sc-1t8cw05-6")
    address_e = [at.get_text() for at in address_tags]
    address.extend(address_e)
    
    price_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .Price__StyledBasePrice-sc-1ayg5nr-2")
    price_e = [pt.get_text() for pt in price_tags]
    price.extend(price_e)
    
    developer_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledDeveloperName-sc-1t8cw05-10")
    developer_e = [dt.get_text() for dt in developer_tags]
    developer.extend(developer_e)
    
    website_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingSiteBlock-sc-1t8cw05-12")
    website_e = [wt.get_text() for wt in website_tags]
    website.extend(website_e)
# Out:
# Type the name of the city:  bucuresti

# %%
residential = pd.DataFrame({
    "name": building_name,
    "address": address,
    "price": price,
    "developer": developer,
    "website": website,
    "date": str(x.strftime("%x"))
})
residential

# To replace a values in a column based on a condition, using numpy.where, use the following syntax.
# DataFrame['column_name'] = numpy.where(condition, new_value, DataFrame.column_name)

residential['website'] = residential['website'].replace("pagina obiect", np.nan)
residential.head(200)
# Out:
#                              name  \
# 0           Casa Presei Residence
# 1                     Parcului 20
# 2            Metropolitan Berceni
# 3               EnVogue Residence
# 4      LSD - Living Spaces Design
# ..                            ...
# 195  Ansamblu Rezidential Crown 3
# 196         Diamantului Residence
# 197        Smart City Residence 3
# 198             Amaireh West Park
# 199         Corvaris 21 Residence
#
#                                                address  \
# 0    Intrarea Străulești, 1C, zona Dămăroaia, secto...
# 1    str. Parcului, 20, zona Piața Presei Libere, s...
# 2    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 3          Drumul Ciorogârla, zona Militari, București
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 195                str. Neamului, 1A, Bragadiru, Ilfov
# 196            str. Diamantului, 166, Bragadiru, Ilfov
# 197            str. Diamantului, 113, Bragadiru, Ilfov
# 198               str. Lacului, zona Ciorogârla, Ilfov
# 199  Drumul Cheile Turzii, zona Olteniței, sector 4...
#
#                                 price                   developer  \
# 0               de la 1 106 € +TVA/m2  New Residences Development
# 1               de la 1 034 € +TVA/m2                      Cordia
# 2                    de la 1 133 €/m2   Metropolitan Developments
# 3                 de la 950 € +TVA/m2           Envogue Residence
# 4    prețul pentru un m2 se clarifică        Living Spaces Design
# ..                                ...                         ...
# 195                  de la 1 000 €/m2             Crown Residence
# 196                    de la 683 €/m2  Smart Imobiliare Bragadiru
# 197               de la 681 € +TVA/m2                         ICD
# 198                    de la 885 €/m2                Amaireh Grup
# 199                    de la 988 €/m2          Corvaris Residence
#
#                               website      date
# 0              casapreseiresidence.ro  01/13/21
# 1                       parcului20.ro  01/13/21
# 2    berceni.metropolitanresidence.ro  01/13/21
# 3                 envogueresidence.ro  01/13/21
# 4                                 NaN  01/13/21
# ..                                ...       ...
# 195                               NaN  01/13/21
# 196                               NaN  01/13/21
# 197                               NaN  01/13/21
# 198                               NaN  01/13/21
# 199                               NaN  01/13/21
#
# [200 rows x 6 columns]

# %%
# Export
residential.to_excel("/Users/robert.radoslav/desktop/residential_" + city + ".xlsx", sheet_name=city)

# Colab export alternative
# from google.colab import files
# residential.to_excel('residential.xlsx') 
# files.download('residential.xlsx')

# %%
import datetime
x = datetime.datetime.now()

# driver = webdriver.Safari()
building_name = []
address = []
price = []
developer = []
website = []

cities = ["Bucuresti", "Cluj", "Timisoara", "Iasi", "Constanta", "Craiova", "Brașov", "Galați", "Ploiești"]
# cities = ["Brasov", "Iasi"]

column_names = ["name", "address", "price", "developer", "website", "city", "date"]
residential = pd.DataFrame(columns = column_names)

for city in cities:
    url = "https://korter.ro/ansambluri-rezidentiale-in-" + city
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    check = soup.find(class_="ListingHeader__StyledComment-sc-6vo33j-2")
    # print(check.prettify())
    [type(item) for item in list(check.children)]
    number = list(check.children)[2]
    number = int(number) 
    number = number / 20
    number_pages = int(number) + 2
    
    # for pg in range(1, number):
    for pg in range(1, number_pages):
        page_num = str(pg)
        url = "https://korter.ro/ansambluri-rezidentiale-in-" + city + "?page=" + page_num
        # page = driver.get(url)
        # soup = BeautifulSoup(driver.page_source, 'html.parser')
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        # print(soup.prettify())

        buildinigs_stream = soup.find(class_="BuildingsStream__StyledCardsWrapper-sc-1umumy-1")

        building_name_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingName-sc-1t8cw05-5")
        building_name_e = [bnt.get_text() for bnt in building_name_tags]
        building_name.extend(building_name_e)

        address_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingLocation-sc-1t8cw05-6")
        address_e = [at.get_text() for at in address_tags]
        address.extend(address_e)

        price_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .Price__StyledBasePrice-sc-1ayg5nr-2")
        price_e = [pt.get_text() for pt in price_tags]
        price.extend(price_e)

        developer_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledDeveloperName-sc-1t8cw05-10")
        developer_e = [dt.get_text() for dt in developer_tags]
        developer.extend(developer_e)

        website_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingSiteBlock-sc-1t8cw05-12")
        website_e = [wt.get_text() for wt in website_tags]
        website.extend(website_e)
        
        residential_city = pd.DataFrame({
            "name": building_name,
            "address": address,
            "price": price,
            "developer": developer,
            "website": website,
            "city": city,
            "date": str(x.strftime("%x"))
        })
        
        residential_city['website'] = residential_city['website'].replace("pagina obiect", np.nan)
        
        residential = residential.append(residential_city, ignore_index = True)

# %%
residential
# Out:
#                              name  \
# 0           Casa Presei Residence
# 1                     Parcului 20
# 2            Metropolitan Berceni
# 3               EnVogue Residence
# 4      LSD - Living Spaces Design
# ...                           ...
# 19938                    Iaz View
# 19939  Rezidential 9 Mai Ploiesti
# 19940       Real Residence Resort
# 19941               Nordis Sinaia
# 19942             Garten Residenz
#
#                                                  address  \
# 0      Intrarea Străulești, 1C, zona Dămăroaia, secto...
# 1      str. Parcului, 20, zona Piața Presei Libere, s...
# 2      șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 3            Drumul Ciorogârla, zona Militari, București
# 4           Balotești, str. Paris, zona Balotești, Ilfov
# ...                                                  ...
# 19938                            Str. Frasinet, 4, Buzau
# 19939  str. Vornicei, 4, zona Cartierul de Vest, Ploi...
# 19940     str. Văleni, 144, zona Transilvaniei, Ploiești
# 19941              Calea Codrului, zona Centrala, Sinaia
# 19942  Aleea Livezilor, comuna Târgșoru Vechi, satul ...
#
#                                   price                         developer  \
# 0                 de la 1 106 € +TVA/m2        New Residences Development
# 1                 de la 1 034 € +TVA/m2                            Cordia
# 2                      de la 1 133 €/m2         Metropolitan Developments
# 3                   de la 950 € +TVA/m2                 Envogue Residence
# 4      prețul pentru un m2 se clarifică              Living Spaces Design
# ...                                 ...                               ...
# 19938             de la 1 000 € +TVA/m2                   Mecan Construct
# 19939                    de la 825 €/m2            Woma Ecoserv Construct
# 19940               de la 790 € +TVA/m2  Helapharm Warehouse Distribution
# 19941  prețul pentru un m2 se clarifică                            Nordis
# 19942               de la 847 € +TVA/m2                  Baupartner Group
#
#                                 website       city      date
# 0                casapreseiresidence.ro  Bucuresti  01/13/21
# 1                         parcului20.ro  Bucuresti  01/13/21
# 2      berceni.metropolitanresidence.ro  Bucuresti  01/13/21
# 3                   envogueresidence.ro  Bucuresti  01/13/21
# 4                                   NaN  Bucuresti  01/13/21
# ...                                 ...        ...       ...
# 19938                               NaN   Ploiești  01/13/21
# 19939                               NaN   Ploiești  01/13/21
# 19940                               NaN   Ploiești  01/13/21
# 19941                               NaN   Ploiești  01/13/21
# 19942                               NaN   Ploiești  01/13/21
#
# [19943 rows x 7 columns]

# %%
# Export
residential.to_excel("/Users/robert.radoslav/desktop/residential.xlsx", sheet_name="All cities")

# Colab export alternative
# from google.colab import files
# residential.to_excel('residential.xlsx') 
# files.download('residential.xlsx')
