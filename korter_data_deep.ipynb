# %% [markdown]
# #### Korter Data Scrappinig

# %%
import pandas as pd
import numpy as np

# https://developer.apple.com/documentation/webkit/testing_with_webdriver_in_safari
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver

from bs4 import BeautifulSoup

import requests
import unittest
import time
import datetime
import re
import datetime

# %% [markdown]
# ##### Old Code

# %%
# driver = webdriver.Safari()
building_name = []
address = []
price = []
developer = []
website = []
href = []

x = datetime.datetime.now()

# city = str(input("Type the name of the city: "))
city = "iași"
url = "https://korter.ro/ansambluri-rezidentiale-in-" + city
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
check = soup.find(class_="ListingHeader__StyledComment-sc-6vo33j-2")
# print(check.prettify())
[type(item) for item in list(check.children)]
number = list(check.children)[2]
number = int(number) 
number = number / 20
number_pages = int(number) + 2

# for pg in range(1, number):
for pg in range(1, number_pages):
    page_num = str(pg)
    url = "https://korter.ro/ansambluri-rezidentiale-in-" + city + "?page=" + page_num
    # page = driver.get(url)
    # soup = BeautifulSoup(driver.page_source, 'html.parser')
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    # print(soup.prettify())
    
    buildinigs_stream = soup.find(class_="BuildingsStream__StyledCardsWrapper-sc-1umumy-1")
    # print(buildinigs_stream.prettify())
    
    building_name_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingName-sc-1t8cw05-5")
    building_name_e = [bnt.get_text() for bnt in building_name_tags]
    building_name.extend(building_name_e)
    
    address_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingLocation-sc-1t8cw05-6")
    address_e = [at.get_text() for at in address_tags]
    address.extend(address_e)
    
    price_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .Price__StyledBasePrice-sc-1ayg5nr-2")
    price_e = [pt.get_text() for pt in price_tags]
    price.extend(price_e)
    
    developer_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledDeveloperName-sc-1t8cw05-10")
    developer_e = [dt.get_text() for dt in developer_tags]
    developer.extend(developer_e)
    
    # website_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingSiteBlock-sc-1t8cw05-12")
    # website_e = [wt.get_text() for wt in website_tags]
    # website.extend(website_e)
    
    # buildinigs_stream_b = soup.find(class_="buildingCard__StyledWrapper-sc-1t8cw05-2 iPKkAv")
    href_tags = buildinigs_stream.find_all('a', class_="Link__StyledLink-sc-1qa6dyr-0 givVbJ buildingCard__StyledMainLink-sc-1t8cw05-0 fjVoPz")
    href_e = [ht.get('href') for ht in href_tags]
    href.extend(href_e)

# %%
list_a = [building_name, address, price, developer, href]
for el in list_a:
    print(len(el))
# Out:
# 90
# 90
# 90
# 90
# 90

# %%
residential = pd.DataFrame({
    "name": building_name,
    "address": address,
    "price": price,
    "developer": developer,
    "date": str(x.strftime("%x")),
    "href": href,
})
residential

# To replace a values in a column based on a condition, using numpy.where, use the following syntax.
# DataFrame['column_name'] = numpy.where(condition, new_value, DataFrame.column_name)

# residential['website'] = residential['website'].replace("pagina obiect", np.nan)
# residential.head(200)
# Out:
#                            name                                       address  \
# 0             Young Residence 2          Calea Chișinăului, zona Baza 3, Iași
# 1                  London House      Aleea Sadoveanu, 70S, zona Carol I, Iași
# 2               Ideal Residence                 str. Bazei, 2, zona Cug, Iași
# 3              Evergreen Towers    str. Aurel Vlaicu, 83, zona Aviației, Iași
# 4                  Cuibul Verde         str. Fundac Ursulea, zona Copou, Iași
# ..                          ...                                           ...
# 85  Cartier Rezidential La Plop  str. Mircea Eliade, zona Valea Ursului, Iași
# 86           Case Mediteraneene    str. Vânătorilor, zona Valea Ursului, Iași
# 87        Casa Blanca Residence               Miroslava - Sat Vorovești, Iași
# 88          Titan Residence Gug                 șos. Nicolina, zona Cug, Iași
# 89                  Astoria Lux           str. Frumoasă, Lunca Cetățuii, Iași
#
#                     price                    developer      date  \
# 0   de la 1 200 € +TVA/m2              Young Residence  01/22/21
# 1        de la 1 077 €/m2            Premium Buildings  01/22/21
# 2     de la 834 € +TVA/m2                Peg Construct  01/22/21
# 3          de la 912 €/m2             CCI Rezidentiale  01/22/21
# 4        de la 1 097 €/m2                 Europartener  01/22/21
# ..                    ...                          ...       ...
# 85         de la 777 €/m2  Cartier Rezidential La Plop  01/22/21
# 86    de la 590 € +TVA/m2           Case Mediteraneene  01/22/21
# 87    de la 500 € +TVA/m2        Casa Blanca Residence  01/22/21
# 88  de la 1 100 € +TVA/m2          Titan Residence Cug  01/22/21
# 89    de la 804 € +TVA/m2                   Gef Abecon  01/22/21
#
#                                  href
# 0             /young-residence-2-ia-i
# 1                  /london-house-iași
# 2               /ideal-residence-iași
# 3              /evergreen-towers-ia-i
# 4                  /cuibul-verde-iasi
# ..                                ...
# 85  /cartier-rezidential-la-plop-iasi
# 86           /case-mediteraneene-iasi
# 87        /casa-blanca-residence-iasi
# 88          /titan-residence-gug-iasi
# 89                  /astoria-lux-iasi
#
# [90 rows x 6 columns]

# %%
for resi in href:
    url_resi = "https://korter.ro" + resi
    page_resi = requests.get(url_resi)
    soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
    table_resi = soup_resi.find(class_="PrimaryTableAttributesBlock__StyledAttributesTable-sc-1gdjixd-0 dRvDKU")

# %%
url_resi = "https://korter.ro/arka-residence-ia-i"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
table_resi = soup_resi.find(class_="PrimaryTableAttributesBlock__StyledAttributesTable-sc-1gdjixd-0 dRvDKU")
print(table_resi.prettify())
# list(table_resi.children)
# Out:
# <table class="PrimaryTableAttributesBlock__StyledAttributesTable-sc-1gdjixd-0 dRvDKU">
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Facilităţi
#   </td>
#   <td>
#    interfon, supermarket
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Încălzire
#   </td>
#   <td>
#    centrală termică proprie
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 bwMMfr">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Lift
#   </td>
#   <td>
#    da
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Mijloace de transport
#   </td>
#   <td>
#    autobuz, tramvai, tren
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Număr clădiri
#   </td>
#   <td>
#    3
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 bwMMfr">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Parcare
#   </td>
#   <td>
#    subterană pe 2 niveluri
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Regim inalțime
#   </td>
#   <td>
#    P+6E / P+8E
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Structură rezistență
#   </td>
#   <td>
#    structura din beton armat cu închideri din cărămidă
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 bwMMfr">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Tip imobil
#   </td>
#   <td>
#    bloc de apartamente
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Ziduri
#   </td>
#   <td>
#    compartimentări interioare din cărămidă
#   </td>
#  </tr>
#  <tr class="TableAttribute__StyledWrapper-xbfqge-0 itZMKd">
#   <td class="TableAttribute__StyledKey-xbfqge-1 ekgYYo">
#    Сurte închisă
#   </td>
#   <td>
#    supraveghere video
#   </td>
#  </tr>
# </table>

# %%
tds_resi_charactersitics = []
tds_resi_charactersitics_tags = table_resi.find_all("td", class_="TableAttribute__StyledKey-xbfqge-1")
tds_resi_charactersitics_tags_e = [tds.get_text() for tds in tds_resi_charactersitics_tags]
tds_resi_charactersitics.extend(tds_resi_charactersitics_tags_e)
tds_resi_charactersitics
# Out:
# ['Facilităţi',
#  'Încălzire',
#  'Lift',
#  'Mijloace de transport',
#  'Număr clădiri',
#  'Parcare',
#  'Regim inalțime',
#  'Structură rezistență',
#  'Tip imobil',
#  'Ziduri',
#  'Сurte închisă']

# %%
tds_resi_charactersitics_expl = []
tds_resi_charactersitics_expl_tags = table_resi.find_all("td", class_=False)
tds_resi_charactersitics_expl_tags_e = [tds.get_text() for tds in tds_resi_charactersitics_expl_tags]
tds_resi_charactersitics_expl.extend(tds_resi_charactersitics_expl_tags_e)
tds_resi_charactersitics_expl
# Out:
# ['interfon, supermarket',
#  'centrală termică proprie',
#  'da',
#  'autobuz, tramvai, tren',
#  '3',
#  'subterană pe 2 niveluri',
#  'P+6E / P+8E',
#  'structura din beton armat cu închideri din cărămidă',
#  'bloc de apartamente',
#  'compartimentări interioare din cărămidă',
#  'supraveghere video']

# %%
charactersitics = pd.DataFrame({
    "characteristic": tds_resi_charactersitics,
    "explanation": tds_resi_charactersitics_expl,
    "href": url_resi,
})
charactersitics
# Out:
#            characteristic                                        explanation  \
# 0              Facilităţi                              interfon, supermarket
# 1               Încălzire                           centrală termică proprie
# 2                    Lift                                                 da
# 3   Mijloace de transport                             autobuz, tramvai, tren
# 4           Număr clădiri                                                  3
# 5                 Parcare                            subterană pe 2 niveluri
# 6          Regim inalțime                                        P+6E / P+8E
# 7    Structură rezistență  structura din beton armat cu închideri din căr...
# 8              Tip imobil                                bloc de apartamente
# 9                  Ziduri            compartimentări interioare din cărămidă
# 10          Сurte închisă                                 supraveghere video
#
#                                                 href
# 0   https://korter.ro/evergreen-towers-ia-i/schițele
# 1   https://korter.ro/evergreen-towers-ia-i/schițele
# 2   https://korter.ro/evergreen-towers-ia-i/schițele
# 3   https://korter.ro/evergreen-towers-ia-i/schițele
# 4   https://korter.ro/evergreen-towers-ia-i/schițele
# 5   https://korter.ro/evergreen-towers-ia-i/schițele
# 6   https://korter.ro/evergreen-towers-ia-i/schițele
# 7   https://korter.ro/evergreen-towers-ia-i/schițele
# 8   https://korter.ro/evergreen-towers-ia-i/schițele
# 9   https://korter.ro/evergreen-towers-ia-i/schițele
# 10  https://korter.ro/evergreen-towers-ia-i/schițele

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
charactersitics.pivot(index="href", columns="characteristic", values="explanation")
# Out:
# characteristic                                               Facilităţi Lift  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  interfon, supermarket   da
#
# characteristic                                     Mijloace de transport  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  autobuz, tramvai, tren
#
# characteristic                                   Număr clădiri  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele             3
#
# characteristic                                                    Parcare  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  subterană pe 2 niveluri
#
# characteristic                                   Regim inalțime  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele    P+6E / P+8E
#
# characteristic                                                                 Structură rezistență  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  structura din beton armat cu închideri din căr...
#
# characteristic                                             Tip imobil  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  bloc de apartamente
#
# characteristic                                                                     Ziduri  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  compartimentări interioare din cărămidă
#
# characteristic                                                   Încălzire  \
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  centrală termică proprie
#
# characteristic                                         Сurte închisă
# href
# https://korter.ro/evergreen-towers-ia-i/schițele  supraveghere video

# %%
charactersitics.transpose()
# Out:
#                                                     0  \
# characteristic                             Facilităţi
# explanation                     interfon, supermarket
# href            https://korter.ro/arka-residence-ia-i
#
#                                                     1  \
# characteristic                              Încălzire
# explanation                  centrală termică proprie
# href            https://korter.ro/arka-residence-ia-i
#
#                                                     2  \
# characteristic                                   Lift
# explanation                                        da
# href            https://korter.ro/arka-residence-ia-i
#
#                                                     3  \
# characteristic                  Mijloace de transport
# explanation                    autobuz, tramvai, tren
# href            https://korter.ro/arka-residence-ia-i
#
#                                                     4  \
# characteristic                          Număr clădiri
# explanation                                         3
# href            https://korter.ro/arka-residence-ia-i
#
#                                                     5  \
# characteristic                                Parcare
# explanation                   subterană pe 2 niveluri
# href            https://korter.ro/arka-residence-ia-i
#
#                                                     6  \
# characteristic                         Regim inalțime
# explanation                               P+6E / P+8E
# href            https://korter.ro/arka-residence-ia-i
#
#                                                                 7  \
# characteristic                               Structură rezistență
# explanation     structura din beton armat cu închideri din căr...
# href                        https://korter.ro/arka-residence-ia-i
#
#                                                     8  \
# characteristic                             Tip imobil
# explanation                       bloc de apartamente
# href            https://korter.ro/arka-residence-ia-i
#
#                                                       9  \
# characteristic                                   Ziduri
# explanation     compartimentări interioare din cărămidă
# href              https://korter.ro/arka-residence-ia-i
#
#                                                    10
# characteristic                          Сurte închisă
# explanation                        supraveghere video
# href            https://korter.ro/arka-residence-ia-i

# %%
# CHARACTERISTIC END

# %%
# SKETCHKES AND PRICES

# %%
url_resi = "https://korter.ro/arka-residence-ia-i"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')

sket_pr_resi_type = []
sket_pr_resi_type_tags = soup_resi.find_all(class_="UnitTypeRow__StyledUnitType-wfbjku-1 bjEpwX")
sket_pr_resi_type_tags_e = [sprt.get_text() for sprt in sket_pr_resi_type_tags]
sket_pr_resi_type.extend(sket_pr_resi_type_tags_e)
sket_pr_resi_type

sket_pr_resi_surface = []
sket_pr_resi_surface_tags = soup_resi.find_all(class_="UnitTypeRow__StyledPriceArea-wfbjku-3 bJnUHx")
sket_pr_resi_surface_tags_e = [sprt.get_text("|", strip=True) for sprt in sket_pr_resi_surface_tags]
sket_pr_resi_surface.extend(sket_pr_resi_surface_tags_e)
sket_pr_resi_surface
# Out:
# ['42|m|2|de la 1 450 € +TVA|pentru m|2|de la 60 900 € +TVA',
#  '43.9|–|59.4|m|2|de la 1 450 € +TVA|pentru m|2|de la 63 655 € +TVA',
#  '63.9|m|2|de la 1 450 € +TVA|pentru m|2|de la 92 655 € +TVA']

# %%
sket_pr_resi_type = []
sket_pr_resi_type_tags = soup_resi.find_all(class_="UnitTypeRow__StyledUnitType-wfbjku-1 bjEpwX")
sket_pr_resi_type_tags_e = [sprt.get_text() for sprt in sket_pr_resi_type_tags]
sket_pr_resi_type.extend(sket_pr_resi_type_tags_e)
sket_pr_resi_type
# Out:
# ['1 camere', '2 camere', '3 camere']

# %%
sket_pr_resi_surface_df = pd.DataFrame({
    "unedited_column": sket_pr_resi_surface,
    "type": sket_pr_resi_type,
    "href": url_resi,
})
sket_pr_resi_surface_df
# Out:
#                                      unedited_column      type  \
# 0  42|m|2|de la 1 450 € +TVA|pentru m|2|de la 60 ...  1 camere
# 1  43.9|–|59.4|m|2|de la 1 450 € +TVA|pentru m|2|...  2 camere
# 2  63.9|m|2|de la 1 450 € +TVA|pentru m|2|de la 9...  3 camere
#
#                                     href
# 0  https://korter.ro/arka-residence-ia-i
# 1  https://korter.ro/arka-residence-ia-i
# 2  https://korter.ro/arka-residence-ia-i

# %%
print(sket_pr_resi_surface_df.unedited_column.apply(lambda x: pd.Series(str(x).split("de la", 2))))
# Out:
#                   0                          1               2
# 0           42|m|2|   1 450 € +TVA|pentru m|2|   60 900 € +TVA
# 1  43.9|–|59.4|m|2|   1 450 € +TVA|pentru m|2|   63 655 € +TVA
# 2         63.9|m|2|   1 450 € +TVA|pentru m|2|   92 655 € +TVA

# %%
sket_pr_resi_surface_df[['surface','price_m2','total_price']] = sket_pr_resi_surface_df.unedited_column.apply( 
   lambda x: pd.Series(str(x).split("de la", 2)))
sket_pr_resi_surface_df
# Out:
#        type                                    unedited_column  \
# 0  1 camere  42|m|2|de la 1 450 € +TVA|pentru m|2|de la 60 ...
# 1  2 camere  43.9|–|59.4|m|2|de la 1 450 € +TVA|pentru m|2|...
# 2  3 camere  63.9|m|2|de la 1 450 € +TVA|pentru m|2|de la 9...
#
#                                     href           surface  \
# 0  https://korter.ro/arka-residence-ia-i           42|m|2|
# 1  https://korter.ro/arka-residence-ia-i  43.9|–|59.4|m|2|
# 2  https://korter.ro/arka-residence-ia-i         63.9|m|2|
#
#                     price_m2     total_price
# 0   1 450 € +TVA|pentru m|2|   60 900 € +TVA
# 1   1 450 € +TVA|pentru m|2|   63 655 € +TVA
# 2   1 450 € +TVA|pentru m|2|   92 655 € +TVA

# %%
sket_pr_resi_surface_df.surface = sket_pr_resi_surface_df.surface.str.replace('|', '')
sket_pr_resi_surface_df.surface = sket_pr_resi_surface_df.surface.str.replace('m2', '')
sket_pr_resi_surface_df.price_m2 = sket_pr_resi_surface_df.price_m2.str.replace('|pentru m|2|', '')
sket_pr_resi_surface_df.price_m2 = sket_pr_resi_surface_df.price_m2.str.replace('|', '')
sket_pr_resi_surface_df = sket_pr_resi_surface_df.drop(['unedited_column'], axis=1)
sket_pr_resi_surface_df
# Out:
#        type                                   href    surface       price_m2  \
# 0  1 camere  https://korter.ro/arka-residence-ia-i         42   1 450 € +TVA
# 1  2 camere  https://korter.ro/arka-residence-ia-i  43.9–59.4   1 450 € +TVA
# 2  3 camere  https://korter.ro/arka-residence-ia-i       63.9   1 450 € +TVA
#
#       total_price
# 0   60 900 € +TVA
# 1   63 655 € +TVA
# 2   92 655 € +TVA

# %%
# STAGES

# %%
url_resi = "https://korter.ro/evergreen-towers-ia-i"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
stage_resi = soup_resi.find(class_="houses__StyledListWrapper-sc-8hboo4-0 gBLHQM")
print(stage_resi.prettify())
# Out:
# <div class="houses__StyledListWrapper-sc-8hboo4-0 gBLHQM">
#  <div class="HouseQueueCard__StyledWrapper-sc-1bay3ay-0 fIuinW">
#   <svg height="24" viewbox="0 0 24 24" width="24">
#    <defs>
#     <path d="M15,11 L15,5.83 C15,5.3 14.79,4.79 14.41,4.42 L12.7,2.71 C12.31,2.32 11.68,2.32 11.29,2.71 L9.59,4.41 C9.21,4.79 9,5.3 9,5.83 L9,7 L5,7 C3.9,7 3,7.9 3,9 L3,19 C3,20.1 3.9,21 5,21 L19,21 C20.1,21 21,20.1 21,19 L21,13 C21,11.9 20.1,11 19,11 L15,11 Z M7,19 L5,19 L5,17 L7,17 L7,19 Z M7,15 L5,15 L5,13 L7,13 L7,15 Z M7,11 L5,11 L5,9 L7,9 L7,11 Z M13,19 L11,19 L11,17 L13,17 L13,19 Z M13,15 L11,15 L11,13 L13,13 L13,15 Z M13,11 L11,11 L11,9 L13,9 L13,11 Z M13,7 L11,7 L11,5 L13,5 L13,7 Z M19,19 L17,19 L17,17 L19,17 L19,19 Z M19,15 L17,15 L17,13 L19,13 L19,15 Z" id="queue-a">
#     </path>
#     <rect height="25" id="queue-c" width="25" x="0" y="0">
#     </rect>
#    </defs>
#    <g fill="none" fill-rule="evenodd">
#     <polygon points="0 0 24 0 24 24 0 24">
#     </polygon>
#     <mask fill="#fff" id="queue-b">
#      <use xlink:href="#queue-a">
#      </use>
#     </mask>
#     <use fill="#9e9e9e" fill-rule="nonzero" xlink:href="#queue-a">
#     </use>
#     <g mask="url(#queue-b)">
#      <use fill="#9e9e9e" xlink:href="#queue-c">
#      </use>
#     </g>
#    </g>
#   </svg>
#   <div class="HouseQueueCard__StyledInfo-sc-1bay3ay-1 jIveRX">
#    <div class="HouseQueueCard__StyledName-sc-1bay3ay-2 daVYvY">
#     Etapa 1
#    </div>
#    <div class="HouseQueueCard__StyledQueueHouses-sc-1bay3ay-3 ifOvBM">
#     Bloc 1, Bloc 2
#    </div>
#    <div>
#     dat în exploatare
#    </div>
#    <div>
#     sunt apartamente în vânzare
#    </div>
#    <div>
#     finalizat
#     <!-- -->
#     –
#     <b>
#      1
#      <!-- -->
#      <!-- -->
#      trimestrul
#      <!-- -->
#      <!-- -->
#      2020
#     </b>
#    </div>
#   </div>
#  </div>
#  <div class="HouseQueueCard__StyledWrapper-sc-1bay3ay-0 fIuinW">
#   <svg height="24" viewbox="0 0 24 24" width="24">
#    <defs>
#     <path d="M15,11 L15,5.83 C15,5.3 14.79,4.79 14.41,4.42 L12.7,2.71 C12.31,2.32 11.68,2.32 11.29,2.71 L9.59,4.41 C9.21,4.79 9,5.3 9,5.83 L9,7 L5,7 C3.9,7 3,7.9 3,9 L3,19 C3,20.1 3.9,21 5,21 L19,21 C20.1,21 21,20.1 21,19 L21,13 C21,11.9 20.1,11 19,11 L15,11 Z M7,19 L5,19 L5,17 L7,17 L7,19 Z M7,15 L5,15 L5,13 L7,13 L7,15 Z M7,11 L5,11 L5,9 L7,9 L7,11 Z M13,19 L11,19 L11,17 L13,17 L13,19 Z M13,15 L11,15 L11,13 L13,13 L13,15 Z M13,11 L11,11 L11,9 L13,9 L13,11 Z M13,7 L11,7 L11,5 L13,5 L13,7 Z M19,19 L17,19 L17,17 L19,17 L19,19 Z M19,15 L17,15 L17,13 L19,13 L19,15 Z" id="queue-a">
#     </path>
#     <rect height="25" id="queue-c" width="25" x="0" y="0">
#     </rect>
#    </defs>
#    <g fill="none" fill-rule="evenodd">
#     <polygon points="0 0 24 0 24 24 0 24">
#     </polygon>
#     <mask fill="#fff" id="queue-b">
#      <use xlink:href="#queue-a">
#      </use>
#     </mask>
#     <use fill="#9e9e9e" fill-rule="nonzero" xlink:href="#queue-a">
#     </use>
#     <g mask="url(#queue-b)">
#      <use fill="#9e9e9e" xlink:href="#queue-c">
#      </use>
#     </g>
#    </g>
#   </svg>
#   <div class="HouseQueueCard__StyledInfo-sc-1bay3ay-1 jIveRX">
#    <div class="HouseQueueCard__StyledName-sc-1bay3ay-2 daVYvY">
#     Etapa 2
#    </div>
#    <div class="HouseQueueCard__StyledQueueHouses-sc-1bay3ay-3 ifOvBM">
#     Bloc 7, Bloc 8
#    </div>
#    <div>
#     necunoscut
#    </div>
#    <div>
#     sunt apartamente în vânzare
#    </div>
#    <div>
#     finalizare
#     <!-- -->
#     –
#     <b>
#      4
#      <!-- -->
#      <!-- -->
#      trimestrul
#      <!-- -->
#      <!-- -->
#      2021
#     </b>
#    </div>
#   </div>
#  </div>
#  <div class="HouseQueueCard__StyledWrapper-sc-1bay3ay-0 fIuinW">
#   <svg height="24" viewbox="0 0 24 24" width="24">
#    <defs>
#     <path d="M15,11 L15,5.83 C15,5.3 14.79,4.79 14.41,4.42 L12.7,2.71 C12.31,2.32 11.68,2.32 11.29,2.71 L9.59,4.41 C9.21,4.79 9,5.3 9,5.83 L9,7 L5,7 C3.9,7 3,7.9 3,9 L3,19 C3,20.1 3.9,21 5,21 L19,21 C20.1,21 21,20.1 21,19 L21,13 C21,11.9 20.1,11 19,11 L15,11 Z M7,19 L5,19 L5,17 L7,17 L7,19 Z M7,15 L5,15 L5,13 L7,13 L7,15 Z M7,11 L5,11 L5,9 L7,9 L7,11 Z M13,19 L11,19 L11,17 L13,17 L13,19 Z M13,15 L11,15 L11,13 L13,13 L13,15 Z M13,11 L11,11 L11,9 L13,9 L13,11 Z M13,7 L11,7 L11,5 L13,5 L13,7 Z M19,19 L17,19 L17,17 L19,17 L19,19 Z M19,15 L17,15 L17,13 L19,13 L19,15 Z" id="queue-a">
#     </path>
#     <rect height="25" id="queue-c" width="25" x="0" y="0">
#     </rect>
#    </defs>
#    <g fill="none" fill-rule="evenodd">
#     <polygon points="0 0 24 0 24 24 0 24">
#     </polygon>
#     <mask fill="#fff" id="queue-b">
#      <use xlink:href="#queue-a">
#      </use>
#     </mask>
#     <use fill="#9e9e9e" fill-rule="nonzero" xlink:href="#queue-a">
#     </use>
#     <g mask="url(#queue-b)">
#      <use fill="#9e9e9e" xlink:href="#queue-c">
#      </use>
#     </g>
#    </g>
#   </svg>
#   <div class="HouseQueueCard__StyledInfo-sc-1bay3ay-1 jIveRX">
#    <div class="HouseQueueCard__StyledName-sc-1bay3ay-2 daVYvY">
#     Etapa 3
#    </div>
#    <div class="HouseQueueCard__StyledQueueHouses-sc-1bay3ay-3 ifOvBM">
#     bloc 5, bloc 6
#    </div>
#    <div>
#     în stadiu de proiectare
#    </div>
#   </div>
#  </div>
#  <div class="HouseQueueCard__StyledWrapper-sc-1bay3ay-0 fIuinW">
#   <svg height="24" viewbox="0 0 24 24" width="24">
#    <defs>
#     <path d="M15,11 L15,5.83 C15,5.3 14.79,4.79 14.41,4.42 L12.7,2.71 C12.31,2.32 11.68,2.32 11.29,2.71 L9.59,4.41 C9.21,4.79 9,5.3 9,5.83 L9,7 L5,7 C3.9,7 3,7.9 3,9 L3,19 C3,20.1 3.9,21 5,21 L19,21 C20.1,21 21,20.1 21,19 L21,13 C21,11.9 20.1,11 19,11 L15,11 Z M7,19 L5,19 L5,17 L7,17 L7,19 Z M7,15 L5,15 L5,13 L7,13 L7,15 Z M7,11 L5,11 L5,9 L7,9 L7,11 Z M13,19 L11,19 L11,17 L13,17 L13,19 Z M13,15 L11,15 L11,13 L13,13 L13,15 Z M13,11 L11,11 L11,9 L13,9 L13,11 Z M13,7 L11,7 L11,5 L13,5 L13,7 Z M19,19 L17,19 L17,17 L19,17 L19,19 Z M19,15 L17,15 L17,13 L19,13 L19,15 Z" id="queue-a">
#     </path>
#     <rect height="25" id="queue-c" width="25" x="0" y="0">
#     </rect>
#    </defs>
#    <g fill="none" fill-rule="evenodd">
#     <polygon points="0 0 24 0 24 24 0 24">
#     </polygon>
#     <mask fill="#fff" id="queue-b">
#      <use xlink:href="#queue-a">
#      </use>
#     </mask>
#     <use fill="#9e9e9e" fill-rule="nonzero" xlink:href="#queue-a">
#     </use>
#     <g mask="url(#queue-b)">
#      <use fill="#9e9e9e" xlink:href="#queue-c">
#      </use>
#     </g>
#    </g>
#   </svg>
#   <div class="HouseQueueCard__StyledInfo-sc-1bay3ay-1 jIveRX">
#    <div class="HouseQueueCard__StyledName-sc-1bay3ay-2 daVYvY">
#     Etapa 4
#    </div>
#    <div class="HouseQueueCard__StyledQueueHouses-sc-1bay3ay-3 ifOvBM">
#     bloc 3, bloc 4
#    </div>
#    <div>
#     în stadiu de proiectare
#    </div>
#   </div>
#  </div>
# </div>

# %%
phases = []
phases_tags = stage_resi.find_all('div', class_="HouseQueueCard__StyledName-sc-1bay3ay-2 daVYvY")
phases_tags_e = [pt.get_text() for pt in phases_tags]
phases.extend(phases_tags_e)
phases
# Out:
# ['Etapa 1', 'Etapa 2', 'Etapa 3', 'Etapa 4']

# %%
blocks = []
blocks_tags = stage_resi.find_all('div', class_="HouseQueueCard__StyledQueueHouses-sc-1bay3ay-3 ifOvBM")
blocks_tags_e = [pt.get_text() for pt in blocks_tags]
blocks.extend(blocks_tags_e)
blocks
# Out:
# ['Bloc 1, Bloc 2', 'Bloc 7, Bloc 8', 'bloc 5, bloc 6', 'bloc 3, bloc 4']

# %%
stages = []
stages_tags = stage_resi.find_all('div', class_="HouseQueueCard__StyledWrapper-sc-1bay3ay-0 fIuinW")
stages_tags_e = [st.get_text("|", strip=True) for st in stages_tags]
stages.extend(stages_tags_e)
stages
# Out:
# ['Etapa 1|Bloc 1, Bloc 2|dat în exploatare|sunt apartamente în vânzare|finalizat|–|1|trimestrul|2020',
#  'Etapa 2|Bloc 7, Bloc 8|necunoscut|sunt apartamente în vânzare|finalizare|–|4|trimestrul|2021',
#  'Etapa 3|bloc 5, bloc 6|în stadiu de proiectare',
#  'Etapa 4|bloc 3, bloc 4|în stadiu de proiectare']

# %%
stages_df = pd.DataFrame({
    "stage_column": stages,
    "href": url_resi,
})
stages_df
# Out:
#                                         stage_column  \
# 0  Etapa 1|Bloc 1, Bloc 2|dat în exploatare|sunt ...
# 1  Etapa 2|Bloc 7, Bloc 8|necunoscut|sunt apartam...
# 2     Etapa 3|bloc 5, bloc 6|în stadiu de proiectare
# 3     Etapa 4|bloc 3, bloc 4|în stadiu de proiectare
#
#                                       href
# 0  https://korter.ro/evergreen-towers-ia-i
# 1  https://korter.ro/evergreen-towers-ia-i
# 2  https://korter.ro/evergreen-towers-ia-i
# 3  https://korter.ro/evergreen-towers-ia-i

# %%
print(stages_df.stage_column.apply(lambda x: pd.Series(str(x).split("|", 4))))
# Out:
#          0               1                        2  \
# 0  Etapa 1  Bloc 1, Bloc 2        dat în exploatare
# 1  Etapa 2  Bloc 7, Bloc 8               necunoscut
# 2  Etapa 3  bloc 5, bloc 6  în stadiu de proiectare
# 3  Etapa 4  bloc 3, bloc 4  în stadiu de proiectare
#
#                              3                               4
# 0  sunt apartamente în vânzare   finalizat|–|1|trimestrul|2020
# 1  sunt apartamente în vânzare  finalizare|–|4|trimestrul|2021
# 2                          NaN                             NaN
# 3                          NaN                             NaN

# %%
stages_df[['elem_1','elem_2','elem_3','elem_4','elem_5']] = stages_df.stage_column.apply( 
   lambda x: pd.Series(str(x).split("|", 4)))
stages_df
# Out:
#                                         stage_column  \
# 0  Etapa 1|Bloc 1, Bloc 2|dat în exploatare|sunt ...
# 1  Etapa 2|Bloc 7, Bloc 8|necunoscut|sunt apartam...
# 2     Etapa 3|bloc 5, bloc 6|în stadiu de proiectare
# 3     Etapa 4|bloc 3, bloc 4|în stadiu de proiectare
#
#                                       href   elem_1          elem_2  \
# 0  https://korter.ro/evergreen-towers-ia-i  Etapa 1  Bloc 1, Bloc 2
# 1  https://korter.ro/evergreen-towers-ia-i  Etapa 2  Bloc 7, Bloc 8
# 2  https://korter.ro/evergreen-towers-ia-i  Etapa 3  bloc 5, bloc 6
# 3  https://korter.ro/evergreen-towers-ia-i  Etapa 4  bloc 3, bloc 4
#
#                     elem_3                       elem_4  \
# 0        dat în exploatare  sunt apartamente în vânzare
# 1               necunoscut  sunt apartamente în vânzare
# 2  în stadiu de proiectare                          NaN
# 3  în stadiu de proiectare                          NaN
#
#                            elem_5
# 0   finalizat|–|1|trimestrul|2020
# 1  finalizare|–|4|trimestrul|2021
# 2                             NaN
# 3                             NaN

# %%
stages_df.elem_5 = stages_df.elem_5.str.replace('[|]', ' ')
stages_df
# Out:
#                                         stage_column  \
# 0  Etapa 1|Bloc 1, Bloc 2|dat în exploatare|sunt ...
# 1  Etapa 2|Bloc 7, Bloc 8|necunoscut|sunt apartam...
# 2     Etapa 3|bloc 5, bloc 6|în stadiu de proiectare
# 3     Etapa 4|bloc 3, bloc 4|în stadiu de proiectare
#
#                                       href   elem_1          elem_2  \
# 0  https://korter.ro/evergreen-towers-ia-i  Etapa 1  Bloc 1, Bloc 2
# 1  https://korter.ro/evergreen-towers-ia-i  Etapa 2  Bloc 7, Bloc 8
# 2  https://korter.ro/evergreen-towers-ia-i  Etapa 3  bloc 5, bloc 6
# 3  https://korter.ro/evergreen-towers-ia-i  Etapa 4  bloc 3, bloc 4
#
#                     elem_3                       elem_4  \
# 0        dat în exploatare  sunt apartamente în vânzare
# 1               necunoscut  sunt apartamente în vânzare
# 2  în stadiu de proiectare                          NaN
# 3  în stadiu de proiectare                          NaN
#
#                                elem_5
# 0   finalizat  –  1  trimestrul  2020
# 1  finalizare  –  4  trimestrul  2021
# 2                                 NaN
# 3                                 NaN

# %%
# STAGES END

# %%
# SKETCHES ALL

# %%
url_resi = "https://korter.ro/evergreen-towers-ia-i/schițele"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')

for tag in soup_resi.find_all(class_="LayoutCard__StyledWrapper-sc-1j6xc9t-1 kvPUf"):
    print (tag.get_text("|", strip=True))
# Out:
# Prețul|47 376 €|Spaţiu|45.25|m|2
# Prețul|41 580 €|Spaţiu|45.6|m|2
# Prețul|63 000 €|Spaţiu|62|m|2
# Prețul|59 220 €|Spaţiu|62|m|2
# Prețul|59 316 €|Spaţiu|62.1|m|2
# Prețul|59 316 €|Spaţiu|62.1|m|2
# Prețul|74 448 €|Spaţiu|78.5|m|2

# %%
url_resi = "https://korter.ro/evergreen-towers-ia-i/schițele"
page_resi = requests.get(url_resi)
sketches_resi = BeautifulSoup(page_resi.content, 'html.parser')

sketches = []
sketches_tags = sketches_resi.find_all(class_="LayoutCard__StyledWrapper-sc-1j6xc9t-1 kvPUf")
sketches_tags_e = [st.get_text("|", strip=True) for st in sketches_tags]
sketches.extend(sketches_tags_e)
sketches
# Out:
# ['Prețul|47 376 €|Spaţiu|45.25|m|2',
#  'Prețul|41 580 €|Spaţiu|45.6|m|2',
#  'Prețul|63 000 €|Spaţiu|62|m|2',
#  'Prețul|59 220 €|Spaţiu|62|m|2',
#  'Prețul|59 316 €|Spaţiu|62.1|m|2',
#  'Prețul|59 316 €|Spaţiu|62.1|m|2',
#  'Prețul|74 448 €|Spaţiu|78.5|m|2']

# %%
sketches_df = pd.DataFrame({
    "sketches_column": sketches,
    "href": url_resi,
})
sketches_df
# Out:
#                     sketches_column  \
# 0  Prețul|47 376 €|Spaţiu|45.25|m|2
# 1   Prețul|41 580 €|Spaţiu|45.6|m|2
# 2     Prețul|63 000 €|Spaţiu|62|m|2
# 3     Prețul|59 220 €|Spaţiu|62|m|2
# 4   Prețul|59 316 €|Spaţiu|62.1|m|2
# 5   Prețul|59 316 €|Spaţiu|62.1|m|2
# 6   Prețul|74 448 €|Spaţiu|78.5|m|2
#
#                                                href
# 0  https://korter.ro/evergreen-towers-ia-i/schițele
# 1  https://korter.ro/evergreen-towers-ia-i/schițele
# 2  https://korter.ro/evergreen-towers-ia-i/schițele
# 3  https://korter.ro/evergreen-towers-ia-i/schițele
# 4  https://korter.ro/evergreen-towers-ia-i/schițele
# 5  https://korter.ro/evergreen-towers-ia-i/schițele
# 6  https://korter.ro/evergreen-towers-ia-i/schițele

# %%
sketches_df[['del1','price','del2','space']] = sketches_df.sketches_column.apply( 
   lambda x: pd.Series(str(x).split("|", 3)))
sketches_df
# Out:
#                     sketches_column  \
# 0  Prețul|47 376 €|Spaţiu|45.25|m|2
# 1   Prețul|41 580 €|Spaţiu|45.6|m|2
# 2     Prețul|63 000 €|Spaţiu|62|m|2
# 3     Prețul|59 220 €|Spaţiu|62|m|2
# 4   Prețul|59 316 €|Spaţiu|62.1|m|2
# 5   Prețul|59 316 €|Spaţiu|62.1|m|2
# 6   Prețul|74 448 €|Spaţiu|78.5|m|2
#
#                                                href    Del1     price    Del2  \
# 0  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  47 376 €  Spaţiu
# 1  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  41 580 €  Spaţiu
# 2  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  63 000 €  Spaţiu
# 3  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  59 220 €  Spaţiu
# 4  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  59 316 €  Spaţiu
# 5  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  59 316 €  Spaţiu
# 6  https://korter.ro/evergreen-towers-ia-i/schițele  Prețul  74 448 €  Spaţiu
#
#        space
# 0  45.25|m|2
# 1   45.6|m|2
# 2     62|m|2
# 3     62|m|2
# 4   62.1|m|2
# 5   62.1|m|2
# 6   78.5|m|2

# %%
url_resi = "https://korter.ro/evergreen-towers-ia-i/schițele"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
for tag in soup_resi.find_all(class_="SecondaryTitle-sc-5neg6l-0 LayoutsByUnitType__StyledSecondaryTitle-sc-1la7dej-1 CwBpC"):
    print (tag.text)
# Out:
# Garsoniere
# 2 camere
# 3 camere

# %%
url_resi = "https://korter.ro/evergreen-towers-ia-i/schițele"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
listing = soup_resi.find(class_="layoutListing__StyledContentWrapper-sc-1j10b4t-0 gzzsaq")
#print(listing.prettify())"
types = listing.find_all(class_="SecondaryTitle-sc-5neg6l-0 LayoutsByUnitType__StyledSecondaryTitle-sc-1la7dej-1 CwBpC")

garsoniera = types[0]
print(garsoniera.prettify())
print (garsoniera.text)

expl = listing.find_all(class_="LayoutCard__StyledWrapper-sc-1j6xc9t-1 kvPUf")
print("***")
print(len(expl))
print("***")
explanation = expl[0]
print (explanation.text)
# Out:
# <h2 class="SecondaryTitle-sc-5neg6l-0 LayoutsByUnitType__StyledSecondaryTitle-sc-1la7dej-1 CwBpC" id="unitType-Garsoniere">
#  Garsoniere
# </h2>
#
# Garsoniere
# ***
# 7
# ***
# Prețul47 376 €Spaţiu45.25 m2

# %%
url_resi = "https://korter.ro/evergreen-towers-ia-i/schițele"
page_resi = requests.get(url_resi)
soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
listing = soup_resi.find(class_="layoutListing__StyledContentWrapper-sc-1j10b4t-0 gzzsaq")
#print(listing.prettify())"
types = listing.find_all(class_="SecondaryTitle-sc-5neg6l-0 LayoutsByUnitType__StyledSecondaryTitle-sc-1la7dej-1 CwBpC")
print(types[0].prettify())

# garsoniera = types[0]
# print(garsoniera.prettify())
# print (garsoniera.text)

# expl = listing.find_all(class_="LayoutCard__StyledWrapper-sc-1j6xc9t-1 kvPUf")
# print("***")
# print(len(expl))
# print("***")
# explanation = expl[0]
# print (explanation.text)

# for i in range(1, len(expl)):
#     print(expl[i].text)
# Out:
# <h2 class="SecondaryTitle-sc-5neg6l-0 LayoutsByUnitType__StyledSecondaryTitle-sc-1la7dej-1 CwBpC" id="unitType-Garsoniere">
#  Garsoniere
# </h2>

# %%
# Export
residential.to_excel("/Users/robert.radoslav/desktop/residential_" + city + ".xlsx", sheet_name=city)

# Colab export alternative
# from google.colab import files
# residential.to_excel('residential.xlsx') 
# files.download('residential.xlsx')

# %%
# SAFEGUARD /// STARTS FROM HERE

# %%
x = datetime.datetime.now()

# CHANGE
# city = str(input("Type the name of the city: "))
# cities = ["Bucuresti", "Cluj", "Timisoara", "Iasi", "Constanta", "Craiova", "Brașov", "Galați", "Ploiești"]
# cities = ["Bucuresti", "Cluj"]
cities = ["Bucuresti", "Cluj", "Timisoara", "Iasi", "Constanta"]

column_names = ["name", "address", "developer", "city", "date", "href", "main_price_from"]
residential = pd.DataFrame(columns = column_names)

for city in cities:
    url = "https://korter.ro/ansambluri-rezidentiale-in-" + city
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    check = soup.find(class_="ListingHeader__StyledComment-sc-6vo33j-2")
    # print(check.prettify())
    # [type(item) for item in list(check.children)]
    number = list(check.children)[2]
    number = int(number) 
    number = number / 20
    number_pages = int(number) + 2
    
    # for pg in range(1, number):
    for pg in range(1, number_pages):
        page_num = str(pg)
        url = "https://korter.ro/ansambluri-rezidentiale-in-" + city + "?page=" + page_num
        # page = driver.get(url)
        # soup = BeautifulSoup(driver.page_source, 'html.parser')
        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        # print(soup.prettify())

        buildinigs_stream = soup.find(class_="BuildingsStream__StyledCardsWrapper-sc-1umumy-1")
        
        building_name = []
        building_name_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingName-sc-1t8cw05-5")
        building_name_e = [bnt.get_text() for bnt in building_name_tags]
        building_name.extend(building_name_e)

        address = []
        address_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingLocation-sc-1t8cw05-6")
        address_e = [at.get_text() for at in address_tags]
        address.extend(address_e)
    
        price = []
        price_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .Price__StyledBasePrice-sc-1ayg5nr-2")
        price_e = [pt.get_text() for pt in price_tags]
        price.extend(price_e)

        developer = []
        developer_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledDeveloperName-sc-1t8cw05-10")
        developer_e = [dt.get_text() for dt in developer_tags]
        developer.extend(developer_e)

        # website = []
        # website_tags = buildinigs_stream.select(".buildingCard__StyledWrapper-sc-1t8cw05-2 .buildingCard__StyledBuildingSiteBlock-sc-1t8cw05-12")
        # website_e = [wt.get_text() for wt in website_tags]
        # website.extend(website_e)
        
        # buildinigs_stream_b = soup.find(class_="buildingCard__StyledWrapper-sc-1t8cw05-2 iPKkAv")
        href = []
        href_tags = buildinigs_stream.find_all('a', class_="Link__StyledLink-sc-1qa6dyr-0 givVbJ buildingCard__StyledMainLink-sc-1t8cw05-0 fjVoPz")
        href_e = [ht.get('href') for ht in href_tags]
        href.extend(href_e)   
        
        residential_city = pd.DataFrame({
            "name": building_name,
            "address": address,
            "developer": developer,
            "city": city,
            "date": str(x.strftime("%x")),
            "href": href,
            "main_price_from": price,
        })

        # residential_city['website'] = residential_city['website'].replace("pagina obiect", np.nan)
        residential = residential.append(residential_city, ignore_index = True)

residential
# Out:
#                            name  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 746      Solid Residence Megara
# 747     Aviatorii Residence III
# 748                  Unirii 19B
# 749     White Pearl Residence 2
# 750                      IBO T7
#
#                                                address  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 746       Aleea Megara, 9, zona Mamaia Nord, Constanța
# 747  Aleea Universității, zona Campus Tomis Nord, C...
# 748     str. Unirii, 19 B, zona Faleza Nord, Constanța
# 749        D 17, zona Mackerel, Mamaia Nord, Constanța
# 750                       str. T7, Năvodari, Constanța
#
#                           developer       city      date  \
# 0                            Cordia  Bucuresti  02/03/21
# 1         Metropolitan Developments  Bucuresti  02/03/21
# 2                   Ideal Construct  Bucuresti  02/03/21
# 3                            Natrom  Bucuresti  02/03/21
# 4              Living Spaces Design  Bucuresti  02/03/21
# ..                              ...        ...       ...
# 746                     Solid House  Constanta  02/03/21
# 747              Aviatori Residence  Constanta  02/03/21
# 748  Sunrise Properties Development  Constanta  02/03/21
# 749                   Mcg Residence  Constanta  02/03/21
# 750      IBO Rezidentiale Constanța  Constanta  02/03/21
#
#                                     href                   main_price_from
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 917 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 746    /solid-residence-megara-constanta             de la 1 150 € +TVA/m2
# 747   /aviatorii-residence-iii-constanta  prețul pentru un m2 se clarifică
# 748                /unirii-19b-constanta             de la 1 350 € +TVA/m2
# 749   /white-pearl-residence-2-constanta  prețul pentru un m2 se clarifică
# 750                    /ibo-t7-constanta               de la 879 € +TVA/m2
#
# [751 rows x 7 columns]

# %%
# href2 is used in the blocks below as well
href2 = residential["href"].tolist()

# To check
# href2 = href2[12:30]

column_names = ["unedited", "type", "href"]
sketches_prices = pd.DataFrame(columns = column_names)

for resi in href2:
    url_resi = "https://korter.ro" + resi
    page_resi = requests.get(url_resi)
    soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
    
    sket_pr_resi_type = []
    sket_pr_resi_type_tags = soup_resi.find_all(class_="UnitTypeRow__StyledUnitType-wfbjku-1 bjEpwX")
    sket_pr_resi_type_tags_e = [sprt.get_text() for sprt in sket_pr_resi_type_tags]
    sket_pr_resi_type.extend(sket_pr_resi_type_tags_e)
    sket_pr_resi_type

    sket_pr_resi_surface = []
    sket_pr_resi_surface_tags = soup_resi.find_all(class_="UnitTypeRow__StyledPriceArea-wfbjku-3 bJnUHx")
    sket_pr_resi_surface_tags_e = [sprt.get_text("|", strip=True) for sprt in sket_pr_resi_surface_tags]
    sket_pr_resi_surface.extend(sket_pr_resi_surface_tags_e)
    sket_pr_resi_surface
    
    sket_pr_resi_surface_df = pd.DataFrame({
        "unedited": sket_pr_resi_surface,
        "type": sket_pr_resi_type,
        "href": url_resi,
    })
    
    sketches_prices = sketches_prices.append(sket_pr_resi_surface_df, ignore_index = True)

sketches_prices.unedited = sketches_prices.unedited.str.replace('|', '')
sketches_prices.unedited = sketches_prices.unedited.str.replace('prețul se clarifică', 'de laprețul se clarifică')
sketches_prices.unedited = sketches_prices.unedited.str.replace('m2', '', 1)
sketches_prices[['area_from','price_m2_from','total_price_from']] = sketches_prices.unedited.apply( 
   lambda x: pd.Series(str(x).split("de la", 2)))
sketches_prices.price_m2_from = sketches_prices.price_m2_from.str.replace('pentru m2', '', 1)
sketches_prices.href = sketches_prices.href.str.replace('https://korter.ro', '', 1)
sketches_prices = sketches_prices.drop(['unedited'], axis=1)
sketches_prices.rename(columns={'href':'href2'}, inplace=True)
sketches_prices
# Out:
#             type                   href2    area_from        price_m2_from  \
# 0       1 camere  /parcului-20-bucuresti   43.5–60.75         1 208 € +TVA
# 1       2 camere  /parcului-20-bucuresti  46.25–89.25         1 034 € +TVA
# 2     2,5 camere  /parcului-20-bucuresti        50.45         1 602 € +TVA
# 3       3 camere  /parcului-20-bucuresti   66.2–119.5         1 086 € +TVA
# 4       4 camere  /parcului-20-bucuresti  106.1–155.6         1 392 € +TVA
# ...          ...                     ...          ...                  ...
# 1719    3 camere   /unirii-19b-constanta         98.7         1 350 € +TVA
# 1720    4 camere   /unirii-19b-constanta        191.9  prețul se clarifică
# 1721   Studiouri       /ibo-t7-constanta   43.85–65.7           879 € +TVA
# 1722    2 camere       /ibo-t7-constanta         80.7           929 € +TVA
# 1723    3 camere       /ibo-t7-constanta        99.95           900 € +TVA
#
#      total_price_from
# 0       70 508 € +TVA
# 1       75 709 € +TVA
# 2       80 846 € +TVA
# 3      103 665 € +TVA
# 4      147 741 € +TVA
# ...               ...
# 1719   133 245 € +TVA
# 1720   215 035 € +TVA
# 1721    47 000 € +TVA
# 1722    75 000 € +TVA
# 1723    90 000 € +TVA
#
# [1724 rows x 5 columns]

# %%
column_names = ["sketches_column", "href"]
sketches_all = pd.DataFrame(columns = column_names)

for resi in href2:
    url_resi = "https://korter.ro" + resi + "/schițele"
    page_resi = requests.get(url_resi)
    sketches_resi = BeautifulSoup(page_resi.content, 'html.parser')

    sketches = []
    sketches_tags = sketches_resi.find_all(class_="LayoutCard__StyledWrapper-sc-1j6xc9t-1 kvPUf")
    sketches_tags_e = [st.get_text("|", strip=True) for st in sketches_tags]
    sketches.extend(sketches_tags_e)
    sketches
    
    sketches_df = pd.DataFrame({
        "sketches_column": sketches,
        "href": url_resi,
    })
    
    sketches_all = sketches_all.append(sketches_df, ignore_index = True)
    
sketches_all[['del1','total_price','del2','total_space']] = sketches_all.sketches_column.apply(
    lambda x: pd.Series(str(x).split("|", 3)))
sketches_all.total_space = sketches_all.total_space.str.replace('|', '')
sketches_all.total_space = sketches_all.total_space.str.replace('m2', '')
sketches_all = sketches_all.drop(['sketches_column', 'del1', 'del2'], axis=1)
sketches_all.href = sketches_all.href.str.replace('https://korter.ro', '', 1)
sketches_all.href = sketches_all.href.str.replace('/schițele', '', 1)
sketches_all.rename(columns={'href':'href2'}, inplace=True)
sketches_all
# Out:
#                        href2          total_price total_space
# 0     /parcului-20-bucuresti        71 610 € +TVA        43.5
# 1     /parcului-20-bucuresti        73 448 € +TVA        55.8
# 2     /parcului-20-bucuresti        73 395 € +TVA       60.75
# 3     /parcului-20-bucuresti  prețul se clarifică        56.5
# 4     /parcului-20-bucuresti        82 845 € +TVA       46.25
# ...                      ...                  ...         ...
# 7006       /ibo-t7-constanta        59 000 € +TVA        58.8
# 7007       /ibo-t7-constanta        56 000 € +TVA        63.7
# 7008       /ibo-t7-constanta        59 000 € +TVA        65.7
# 7009       /ibo-t7-constanta        75 000 € +TVA        80.7
# 7010       /ibo-t7-constanta        90 000 € +TVA       99.95
#
# [7011 rows x 3 columns]

# %%
column_names = ["characteristic", "explanation", "href2"]
charactersitics_all = pd.DataFrame(columns = column_names)

for resi in href2:
    url_resi = "https://korter.ro" + resi
    page_resi = requests.get(url_resi)
    soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
    table_resi = soup_resi.find(class_="PrimaryTableAttributesBlock__StyledAttributesTable-sc-1gdjixd-0 dRvDKU")
    web_resi = soup_resi.find(class_="Link__StyledLink-sc-1qa6dyr-0 fvupyZ")
    
    tds_resi_charactersitics = []
    tds_resi_charactersitics_tags = table_resi.find_all("td", class_="TableAttribute__StyledKey-xbfqge-1")
    tds_resi_charactersitics_tags_e = [tds.get_text() for tds in tds_resi_charactersitics_tags]
    tds_resi_charactersitics.extend(tds_resi_charactersitics_tags_e)
    tds_resi_charactersitics
    
    tds_resi_charactersitics_expl = []
    tds_resi_charactersitics_expl_tags = table_resi.find_all("td", class_=False)
    tds_resi_charactersitics_expl_tags_e = [tds.get_text() for tds in tds_resi_charactersitics_expl_tags]
    tds_resi_charactersitics_expl.extend(tds_resi_charactersitics_expl_tags_e)
    tds_resi_charactersitics_expl
    
    charactersitics = pd.DataFrame({
        "characteristic": tds_resi_charactersitics,
        "explanation": tds_resi_charactersitics_expl,
        "href2": url_resi,
    })
    
    charactersitics_all = charactersitics_all.append(charactersitics)

charactersitics_all.href2 = charactersitics_all.href2.str.replace('https://korter.ro', '', 1)
charactersitics_all
# Out:
#            characteristic                                        explanation  \
# 0              Facilităţi                                           interfon
# 1               Încălzire  centrală de apartament, încălzire în pardoseal...
# 2                    Lift                                     lift Schindler
# 3   Mijloace de transport                                            autobuz
# 4       Număr apartamente                                                 15
# ..                    ...                                                ...
# 5          Regim inalțime                                               P+4E
# 6    Structură rezistență  structura din beton armat cu închideri din căr...
# 7              Tip imobil                                      bloc boutique
# 8                  Ziduri         compartimentări interioare din gips carton
# 9           Сurte închisă                                      videointerfon
#
#                    href2
# 0   /ceda-home-bucuresti
# 1   /ceda-home-bucuresti
# 2   /ceda-home-bucuresti
# 3   /ceda-home-bucuresti
# 4   /ceda-home-bucuresti
# ..                   ...
# 5   /pipera-46-bucuresti
# 6   /pipera-46-bucuresti
# 7   /pipera-46-bucuresti
# 8   /pipera-46-bucuresti
# 9   /pipera-46-bucuresti
#
# [196 rows x 3 columns]

# %%
href2 = residential["href"].tolist()

# To check
# href2 = href2[12:30]

column_names = ["website_link", "href2"]
website_all = pd.DataFrame(columns = column_names)

for resi in href3:   
    url_resi = "https://korter.ro" + resi
    page_resi = requests.get(url_resi)
    soup_resi = BeautifulSoup(page_resi.content, 'html.parser')
    external_links_resi = soup_resi.find_all(class_="ExternalLinks__StyledWrapper-sc-6pqnoc-1 eSjnUu")
    
    website_link = []
    website_e = [elr.get_text("|", strip=True) for elr in external_links_resi]
    website_link.extend(website_e)

    websites = pd.DataFrame({
        "website_link": website_link,
        "href2": url_resi,
    })
    
    website_all = website_all.append(websites)

website_all.href2 = website_all.href2.str.replace('https://korter.ro', '', 1)
website_all[['del1','website','del2']] = website_all.website_link.apply(
    lambda x: pd.Series(str(x).split("|", 2)))
website_all = website_all.drop(['website_link', 'del1', 'del2'], axis=1)
website_all
# Out:
#                                     href2                         website
# 0    /luxuria-domenii-residence-bucurești            luxuria-residence.ro
# 0            /yola-71-residence-bucuresti                       yola71.ro
# 0                       /victoriei_Luxury              victorieiluxury.ro
# 0            /tarraco-residence-bucuresti                 Pagina Oficială
# 0                 /win-herastraubucuresti                win-herastrau.ro
# 0               /pipera-gardens-bucuresti                      ospinas.ro
# 0     /drumul-taberei-residence-bucurești      drumultaberei-residence.ro
# 0                /panorama-city-bucuresti                 panoramacity.ro
# 0       /architecture-residence-bucuresti                 Pagina oficială
# 0   /splaiul-unirii-residence-2-bucuresti  mihaibravu.deluxeapartments.ro
# 0     /atlas-residence-aviatiei-bucuresti     aviatiei.atlas-residence.ro
# 0       /rezidential-orhideelor-4-chiajna      rezidential-orhideelor2.ro
# 0        /new-residence-village-bucuresti            ardc-residentials.ro
# 0            /otopeni-residence-bucuresti            otopeni-residence.ro
# 0              /odyssey-baneasa-bucuresti                      imoteca.ro
# 0                    /pipera-46-bucuresti                     pipera46.ro
# 0  /insignia-residence-militari-bucuresti           insigniaproperties.ro

# %%
# MERGING IT ALL

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html
charactersitics_all = charactersitics_all.pivot(index="href2", columns="characteristic", values="explanation")
charactersitics_all.reset_index(inplace = True) 

# https://focaalvarez.medium.com/vlookup-and-index-match-equivalences-in-pandas-160ac2910399
residential.rename(columns={'href':'href2'}, inplace=True)
table_all_characteristics = residential.merge(charactersitics_all,how='left',on='href2')
table_all_characteristics
# Out:
#                            name  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 479           Proiect Burebista
# 480          Proiect Anton Pann
# 481                       Wings
# 482          Brancusi Residence
# 483      City Comfort Residence
#
#                                                address  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 479  str. Burebista, 8, zona Parcul Feroviarilor, C...
# 480  str. Anton Pann, 10-16, zona Mărăști, Cluj-Napoca
# 481               str. Frunzisului, 88A, Cluj - Napoca
# 482  str. Constantin Brâncuși, 128, zona Andrei Mur...
# 483           str. Razoare, zona Floresti, Cluj-Napoca
#
#                      developer       city      date  \
# 0                       Cordia  Bucuresti  02/03/21
# 1    Metropolitan Developments  Bucuresti  02/03/21
# 2              Ideal Construct  Bucuresti  02/03/21
# 3                       Natrom  Bucuresti  02/03/21
# 4         Living Spaces Design  Bucuresti  02/03/21
# ..                         ...        ...       ...
# 479          SC SDC Imobiliare       Cluj  02/03/21
# 480          SC SDC Imobiliare       Cluj  02/03/21
# 481              Studium Green       Cluj  02/03/21
# 482         Brancusi Residence       Cluj  02/03/21
# 483     City Comfort Residence       Cluj  02/03/21
#
#                                    href2                   main_price_from  \
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 872 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 479        /proiect-burebista-clujnapoca  prețul pentru un m2 se clarifică
# 480       /proiect-anton-pann-clujnapoca  prețul pentru un m2 se clarifică
# 481                   /wings-cluj-napoca             de la 1 350 € +TVA/m2
# 482       /brancusi-residence-clujnapoca             de la 1 751 € +TVA/m2
# 483   /city-comfort-residence-clujnapoca             de la 1 073 € +TVA/m2
#
#     Facilităţi Lift Mijloace de transport Număr apartamente Număr clădiri  \
# 0          NaN  NaN                   NaN               NaN           NaN
# 1          NaN  NaN                   NaN               NaN           NaN
# 2          NaN  NaN                   NaN               NaN           NaN
# 3          NaN  NaN                   NaN               NaN           NaN
# 4          NaN  NaN                   NaN               NaN           NaN
# ..         ...  ...                   ...               ...           ...
# 479        NaN  NaN                   NaN               NaN           NaN
# 480        NaN  NaN                   NaN               NaN           NaN
# 481        NaN  NaN                   NaN               NaN           NaN
# 482        NaN  NaN                   NaN               NaN           NaN
# 483        NaN  NaN                   NaN               NaN           NaN
#
#     Parcare Regim inalțime Structură rezistență Tip imobil Ziduri Încălzire  \
# 0       NaN            NaN                  NaN        NaN    NaN       NaN
# 1       NaN            NaN                  NaN        NaN    NaN       NaN
# 2       NaN            NaN                  NaN        NaN    NaN       NaN
# 3       NaN            NaN                  NaN        NaN    NaN       NaN
# 4       NaN            NaN                  NaN        NaN    NaN       NaN
# ..      ...            ...                  ...        ...    ...       ...
# 479     NaN            NaN                  NaN        NaN    NaN       NaN
# 480     NaN            NaN                  NaN        NaN    NaN       NaN
# 481     NaN            NaN                  NaN        NaN    NaN       NaN
# 482     NaN            NaN                  NaN        NaN    NaN       NaN
# 483     NaN            NaN                  NaN        NaN    NaN       NaN
#
#     Сurte închisă
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 479           NaN
# 480           NaN
# 481           NaN
# 482           NaN
# 483           NaN
#
# [484 rows x 19 columns]

# %%
sketches_prices_2 = sketches_prices.pivot(index="href2", columns="type", values="price_m2_from")
sketches_prices_2.reset_index(inplace = True)

# sketches_prices_2 = sketches_prices.add_suffix('_price_m2_from')
# col_dict = {'type_price_m2_from': 'type', 'href2_price_m2_from': 'href2'} ## key→old name, value→new name
# sketches_prices_2.columns = [col_dict.get(x, x) for x in sketches_prices_2.columns]
sketches_prices_2
# Out:
# type                                href2 1 camere       2 camere  \
# 0              /air-residence-2-bucuresti      NaN   1 497 € +TVA
# 1       /architecture-residence-bucuresti      NaN   2 000 € +TVA
# 2     /atlas-residence-aviatiei-bucuresti      NaN   1 650 € +TVA
# 3                    /ceda-home-bucuresti      NaN     892 € +TVA
# 4     /drumul-taberei-residence-bucurești      NaN          49.45
# 5        /new-residence-village-bucuresti      NaN            NaN
# 6              /odyssey-baneasa-bucuresti      NaN            NaN
# 7            /otopeni-residence-bucuresti      NaN   1 147 € +TVA
# 8                /panorama-city-bucuresti    884 €          833 €
# 9                    /pipera-46-bucuresti      NaN   2 000 € +TVA
# 10              /pipera-gardens-bucuresti      NaN            NaN
# 11      /rezidential-orhideelor-4-chiajna    723 €          687 €
# 12           /tarraco-residence-bucuresti      NaN            NaN
# 13                      /victoriei_Luxury      NaN   1 863 € +TVA
# 14           /yola-71-residence-bucuresti      NaN        1 203 €
#
# type             3 camere 3 camereduplex       4 camere CaseCasa Tip A1  \
# 0                     NaN            NaN            NaN             NaN
# 1                     NaN            NaN            NaN             NaN
# 2            1 439 € +TVA            NaN   1 814 € +TVA             NaN
# 3              927 € +TVA            NaN     900 € +TVA             NaN
# 4                   71.69            NaN            NaN             NaN
# 5                     NaN            NaN            NaN    1 429 € +TVA
# 6            1 510 € +TVA            NaN            NaN             NaN
# 7            1 153 € +TVA            NaN            NaN             NaN
# 8                   868 €            NaN            NaN             NaN
# 9            2 000 € +TVA            NaN            NaN             NaN
# 10                    NaN            NaN            NaN             NaN
# 11                  834 €            NaN          816 €             NaN
# 12                    NaN   1 232 € +TVA            NaN             NaN
# 13    prețul se clarifică            NaN            NaN             NaN
# 14                1 202 €            NaN            NaN             NaN
#
# type Duplex-uri           Garsoniere        Penthouse-uri      Studiouri  \
# 0           NaN                  NaN                  NaN            NaN
# 1           NaN                  NaN                  NaN            NaN
# 2           NaN                  NaN                  NaN            NaN
# 3           NaN                  NaN                  NaN            NaN
# 4         75.82                30.97                  NaN            NaN
# 5           NaN                  NaN                  NaN            NaN
# 6           NaN                  NaN                  NaN            NaN
# 7           NaN  prețul se clarifică                  NaN            NaN
# 8           NaN                  NaN                  NaN            NaN
# 9           NaN                  NaN                  NaN            NaN
# 10          NaN                  NaN                  NaN            NaN
# 11          NaN                  NaN                  NaN            NaN
# 12          NaN                  NaN                  NaN   1 164 € +TVA
# 13          NaN                  NaN  prețul se clarifică            NaN
# 14          NaN              1 011 €                  NaN            NaN
#
# type      Vile
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10     1 195 €
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN

# %%
table_all_char_sketpri = table_all_characteristics.merge(sketches_prices_2, how="left", on="href2")
table_all_char_sketpri
# Out:
#                            name  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 479           Proiect Burebista
# 480          Proiect Anton Pann
# 481                       Wings
# 482          Brancusi Residence
# 483      City Comfort Residence
#
#                                                address  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 479  str. Burebista, 8, zona Parcul Feroviarilor, C...
# 480  str. Anton Pann, 10-16, zona Mărăști, Cluj-Napoca
# 481               str. Frunzisului, 88A, Cluj - Napoca
# 482  str. Constantin Brâncuși, 128, zona Andrei Mur...
# 483           str. Razoare, zona Floresti, Cluj-Napoca
#
#                      developer       city      date  \
# 0                       Cordia  Bucuresti  02/03/21
# 1    Metropolitan Developments  Bucuresti  02/03/21
# 2              Ideal Construct  Bucuresti  02/03/21
# 3                       Natrom  Bucuresti  02/03/21
# 4         Living Spaces Design  Bucuresti  02/03/21
# ..                         ...        ...       ...
# 479          SC SDC Imobiliare       Cluj  02/03/21
# 480          SC SDC Imobiliare       Cluj  02/03/21
# 481              Studium Green       Cluj  02/03/21
# 482         Brancusi Residence       Cluj  02/03/21
# 483     City Comfort Residence       Cluj  02/03/21
#
#                                    href2                   main_price_from  \
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 872 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 479        /proiect-burebista-clujnapoca  prețul pentru un m2 se clarifică
# 480       /proiect-anton-pann-clujnapoca  prețul pentru un m2 se clarifică
# 481                   /wings-cluj-napoca             de la 1 350 € +TVA/m2
# 482       /brancusi-residence-clujnapoca             de la 1 751 € +TVA/m2
# 483   /city-comfort-residence-clujnapoca             de la 1 073 € +TVA/m2
#
#     Facilităţi Lift Mijloace de transport  ... 2 camere 3 camere  \
# 0          NaN  NaN                   NaN  ...      NaN      NaN
# 1          NaN  NaN                   NaN  ...      NaN      NaN
# 2          NaN  NaN                   NaN  ...      NaN      NaN
# 3          NaN  NaN                   NaN  ...      NaN      NaN
# 4          NaN  NaN                   NaN  ...      NaN      NaN
# ..         ...  ...                   ...  ...      ...      ...
# 479        NaN  NaN                   NaN  ...      NaN      NaN
# 480        NaN  NaN                   NaN  ...      NaN      NaN
# 481        NaN  NaN                   NaN  ...      NaN      NaN
# 482        NaN  NaN                   NaN  ...      NaN      NaN
# 483        NaN  NaN                   NaN  ...      NaN      NaN
#
#     3 camereduplex 4 camere CaseCasa Tip A1 Duplex-uri Garsoniere  \
# 0              NaN      NaN             NaN        NaN        NaN
# 1              NaN      NaN             NaN        NaN        NaN
# 2              NaN      NaN             NaN        NaN        NaN
# 3              NaN      NaN             NaN        NaN        NaN
# 4              NaN      NaN             NaN        NaN        NaN
# ..             ...      ...             ...        ...        ...
# 479            NaN      NaN             NaN        NaN        NaN
# 480            NaN      NaN             NaN        NaN        NaN
# 481            NaN      NaN             NaN        NaN        NaN
# 482            NaN      NaN             NaN        NaN        NaN
# 483            NaN      NaN             NaN        NaN        NaN
#
#     Penthouse-uri Studiouri Vile
# 0             NaN       NaN  NaN
# 1             NaN       NaN  NaN
# 2             NaN       NaN  NaN
# 3             NaN       NaN  NaN
# 4             NaN       NaN  NaN
# ..            ...       ...  ...
# 479           NaN       NaN  NaN
# 480           NaN       NaN  NaN
# 481           NaN       NaN  NaN
# 482           NaN       NaN  NaN
# 483           NaN       NaN  NaN
#
# [484 rows x 30 columns]

# %%
# Use str.extract and pass a regex pattern to extract just the numeric parts
# sketches_all_2.total_price = sketches_all_2.total_price.str.extract('(\d+)', expand=False)
# sketches_all_2.total_space = sketches_all_2.total_space.str.encode("ascii", "ignore")
# sketches_all_2.total_space = sketches_all_2.total_space.astype(int)

sketches_all_2 = sketches_all.copy()
sketches_all_2.total_price = sketches_all_2.total_price.str.replace('€', '')
sketches_all_2.total_price = sketches_all_2.total_price.str.replace('[+TVA]', '')
sketches_all_2.total_price = sketches_all_2.total_price.str.replace(r"[a-zA-Z]",'')
sketches_all_2.total_price = sketches_all_2.total_price.str.replace("[ț ţ ă â]", '')
sketches_all_2.total_space = sketches_all_2.total_space.str.replace(r"[a-zA-Z]",'')
sketches_all_2.total_space = sketches_all_2.total_space.str.replace("[ț ţ â ă]", '')

# https://stackoverflow.com/questions/15891038/change-column-type-in-pandas
# df["a"] = pd.to_numeric(df["a"])
sketches_all_2.total_space = pd.to_numeric(sketches_all_2.total_space)
sketches_all_2.total_price = pd.to_numeric(sketches_all_2.total_price)
sketches_all_2.dtypes

sketches_all_2['mean_price'] = sketches_all_2['total_price'] / sketches_all_2['total_space']
sketches_all_2

sketches_all_3 = sketches_all_2.groupby('href2')['mean_price'].mean()
sketches_all_3

sketches_all_4 = pd.DataFrame(data=sketches_all_3)
sketches_all_4
# Out:
#                                        mean_price
# href2
# /air-residence-2-bucuresti               1,537.16
# /architecture-residence-bucuresti        2,000.00
# /atlas-residence-aviatiei-bucuresti      1,743.04
# /ceda-home-bucuresti                       946.70
# /drumul-taberei-residence-bucurești           nan
# /luxuria-domenii-residence-bucurești          nan
# /new-residence-village-bucuresti         1,505.00
# /odyssey-baneasa-bucuresti               1,538.46
# /otopeni-residence-bucuresti             1,153.20
# /panorama-city-bucuresti                   877.17
# /pipera-46-bucuresti                     2,000.00
# /pipera-gardens-bucuresti                1,195.12
# /rezidential-orhideelor-4-chiajna          739.98
# /splaiul-unirii-residence-2-bucuresti         nan
# /tarraco-residence-bucuresti             1,294.89
# /victoriei_Luxury                        1,863.11
# /yola-71-residence-bucuresti             1,138.58

# %%
sketches_all_5 = sketches_all.copy()
sketches_all_5.total_price = sketches_all_5.total_price.str.replace('€', '')
sketches_all_5.total_price = sketches_all_5.total_price.str.replace('[+TVA]', '')
sketches_all_5.total_price = sketches_all_5.total_price.str.replace(r"[a-zA-Z]",'')
sketches_all_5.total_price = sketches_all_5.total_price.str.replace("[ț ţ ă â]", '')
sketches_all_5.total_space = sketches_all_5.total_space.str.replace(r"[a-zA-Z]",'')
sketches_all_5.total_space = sketches_all_5.total_space.str.replace("[ț ţ â ă]", '')

sketches_all_5.total_space = pd.to_numeric(sketches_all_5.total_space)
sketches_all_5.total_price = pd.to_numeric(sketches_all_5.total_price)
sketches_all_5.dtypes

sketches_all_6 = sketches_all_5.groupby('href2')['total_space'].sum()
sketches_all_6

sketches_all_7 = pd.DataFrame(data=sketches_all_6)
sketches_all_7
# Out:
#                                        total_space
# href2
# /air-residence-2-bucuresti                  151.76
# /architecture-residence-bucuresti           196.20
# /atlas-residence-aviatiei-bucuresti       2,915.12
# /ceda-home-bucuresti                      1,800.26
# /drumul-taberei-residence-bucurești           0.00
# /luxuria-domenii-residence-bucurești      1,760.10
# /new-residence-village-bucuresti            122.10
# /odyssey-baneasa-bucuresti                  210.60
# /otopeni-residence-bucuresti                605.10
# /panorama-city-bucuresti                  1,465.60
# /pipera-46-bucuresti                        870.90
# /pipera-gardens-bucuresti                   820.00
# /rezidential-orhideelor-4-chiajna           324.21
# /splaiul-unirii-residence-2-bucuresti       882.80
# /tarraco-residence-bucuresti                561.21
# /victoriei_Luxury                           856.29
# /yola-71-residence-bucuresti                520.95

# %%
table_all_char_sketpri_meanpr = table_all_char_sketpri.merge(sketches_all_4, how="left", on="href2")
table_all_char_sketpri_meanpr_tspace = table_all_char_sketpri_meanpr.merge(sketches_all_7, how="left", on="href2")
table_all_char_sketpri_meanpr_tspace
# Out:
#                            name  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 479           Proiect Burebista
# 480          Proiect Anton Pann
# 481                       Wings
# 482          Brancusi Residence
# 483      City Comfort Residence
#
#                                                address  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 479  str. Burebista, 8, zona Parcul Feroviarilor, C...
# 480  str. Anton Pann, 10-16, zona Mărăști, Cluj-Napoca
# 481               str. Frunzisului, 88A, Cluj - Napoca
# 482  str. Constantin Brâncuși, 128, zona Andrei Mur...
# 483           str. Razoare, zona Floresti, Cluj-Napoca
#
#                      developer       city      date  \
# 0                       Cordia  Bucuresti  02/03/21
# 1    Metropolitan Developments  Bucuresti  02/03/21
# 2              Ideal Construct  Bucuresti  02/03/21
# 3                       Natrom  Bucuresti  02/03/21
# 4         Living Spaces Design  Bucuresti  02/03/21
# ..                         ...        ...       ...
# 479          SC SDC Imobiliare       Cluj  02/03/21
# 480          SC SDC Imobiliare       Cluj  02/03/21
# 481              Studium Green       Cluj  02/03/21
# 482         Brancusi Residence       Cluj  02/03/21
# 483     City Comfort Residence       Cluj  02/03/21
#
#                                    href2                   main_price_from  \
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 872 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 479        /proiect-burebista-clujnapoca  prețul pentru un m2 se clarifică
# 480       /proiect-anton-pann-clujnapoca  prețul pentru un m2 se clarifică
# 481                   /wings-cluj-napoca             de la 1 350 € +TVA/m2
# 482       /brancusi-residence-clujnapoca             de la 1 751 € +TVA/m2
# 483   /city-comfort-residence-clujnapoca             de la 1 073 € +TVA/m2
#
#     Facilităţi Lift Mijloace de transport  ... 3 camereduplex 4 camere  \
# 0          NaN  NaN                   NaN  ...            NaN      NaN
# 1          NaN  NaN                   NaN  ...            NaN      NaN
# 2          NaN  NaN                   NaN  ...            NaN      NaN
# 3          NaN  NaN                   NaN  ...            NaN      NaN
# 4          NaN  NaN                   NaN  ...            NaN      NaN
# ..         ...  ...                   ...  ...            ...      ...
# 479        NaN  NaN                   NaN  ...            NaN      NaN
# 480        NaN  NaN                   NaN  ...            NaN      NaN
# 481        NaN  NaN                   NaN  ...            NaN      NaN
# 482        NaN  NaN                   NaN  ...            NaN      NaN
# 483        NaN  NaN                   NaN  ...            NaN      NaN
#
#     CaseCasa Tip A1 Duplex-uri Garsoniere Penthouse-uri Studiouri Vile  \
# 0               NaN        NaN        NaN           NaN       NaN  NaN
# 1               NaN        NaN        NaN           NaN       NaN  NaN
# 2               NaN        NaN        NaN           NaN       NaN  NaN
# 3               NaN        NaN        NaN           NaN       NaN  NaN
# 4               NaN        NaN        NaN           NaN       NaN  NaN
# ..              ...        ...        ...           ...       ...  ...
# 479             NaN        NaN        NaN           NaN       NaN  NaN
# 480             NaN        NaN        NaN           NaN       NaN  NaN
# 481             NaN        NaN        NaN           NaN       NaN  NaN
# 482             NaN        NaN        NaN           NaN       NaN  NaN
# 483             NaN        NaN        NaN           NaN       NaN  NaN
#
#     mean_price total_space
# 0          nan         nan
# 1          nan         nan
# 2          nan         nan
# 3          nan         nan
# 4          nan         nan
# ..         ...         ...
# 479        nan         nan
# 480        nan         nan
# 481        nan         nan
# 482        nan         nan
# 483        nan         nan
#
# [484 rows x 32 columns]

# %%
table_all_char_sketpri_meanpr_tspace_w = table_all_char_sketpri_meanpr_tspace.merge(website_all, how="left", on="href2")
table_all_char_sketpri_meanpr_tspace_w
# Out:
#                            name  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 479           Proiect Burebista
# 480          Proiect Anton Pann
# 481                       Wings
# 482          Brancusi Residence
# 483      City Comfort Residence
#
#                                                address  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 479  str. Burebista, 8, zona Parcul Feroviarilor, C...
# 480  str. Anton Pann, 10-16, zona Mărăști, Cluj-Napoca
# 481               str. Frunzisului, 88A, Cluj - Napoca
# 482  str. Constantin Brâncuși, 128, zona Andrei Mur...
# 483           str. Razoare, zona Floresti, Cluj-Napoca
#
#                      developer       city      date  \
# 0                       Cordia  Bucuresti  02/03/21
# 1    Metropolitan Developments  Bucuresti  02/03/21
# 2              Ideal Construct  Bucuresti  02/03/21
# 3                       Natrom  Bucuresti  02/03/21
# 4         Living Spaces Design  Bucuresti  02/03/21
# ..                         ...        ...       ...
# 479          SC SDC Imobiliare       Cluj  02/03/21
# 480          SC SDC Imobiliare       Cluj  02/03/21
# 481              Studium Green       Cluj  02/03/21
# 482         Brancusi Residence       Cluj  02/03/21
# 483     City Comfort Residence       Cluj  02/03/21
#
#                                    href2                   main_price_from  \
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 872 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 479        /proiect-burebista-clujnapoca  prețul pentru un m2 se clarifică
# 480       /proiect-anton-pann-clujnapoca  prețul pentru un m2 se clarifică
# 481                   /wings-cluj-napoca             de la 1 350 € +TVA/m2
# 482       /brancusi-residence-clujnapoca             de la 1 751 € +TVA/m2
# 483   /city-comfort-residence-clujnapoca             de la 1 073 € +TVA/m2
#
#     Facilităţi Lift Mijloace de transport  ... 4 camere CaseCasa Tip A1  \
# 0          NaN  NaN                   NaN  ...      NaN             NaN
# 1          NaN  NaN                   NaN  ...      NaN             NaN
# 2          NaN  NaN                   NaN  ...      NaN             NaN
# 3          NaN  NaN                   NaN  ...      NaN             NaN
# 4          NaN  NaN                   NaN  ...      NaN             NaN
# ..         ...  ...                   ...  ...      ...             ...
# 479        NaN  NaN                   NaN  ...      NaN             NaN
# 480        NaN  NaN                   NaN  ...      NaN             NaN
# 481        NaN  NaN                   NaN  ...      NaN             NaN
# 482        NaN  NaN                   NaN  ...      NaN             NaN
# 483        NaN  NaN                   NaN  ...      NaN             NaN
#
#     Duplex-uri Garsoniere Penthouse-uri Studiouri Vile mean_price total_space  \
# 0          NaN        NaN           NaN       NaN  NaN        nan         nan
# 1          NaN        NaN           NaN       NaN  NaN        nan         nan
# 2          NaN        NaN           NaN       NaN  NaN        nan         nan
# 3          NaN        NaN           NaN       NaN  NaN        nan         nan
# 4          NaN        NaN           NaN       NaN  NaN        nan         nan
# ..         ...        ...           ...       ...  ...        ...         ...
# 479        NaN        NaN           NaN       NaN  NaN        nan         nan
# 480        NaN        NaN           NaN       NaN  NaN        nan         nan
# 481        NaN        NaN           NaN       NaN  NaN        nan         nan
# 482        NaN        NaN           NaN       NaN  NaN        nan         nan
# 483        NaN        NaN           NaN       NaN  NaN        nan         nan
#
#     website
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 479     NaN
# 480     NaN
# 481     NaN
# 482     NaN
# 483     NaN
#
# [484 rows x 33 columns]

# %%
# Export
table_all_char_sketpri_meanpr_tspace_w.to_excel("/Users/robert.radoslav/desktop/table_all_char_sketpri_meanpr_tspace_w.xlsx", sheet_name="All cities")

# Colab export alternative
# from google.colab import files
# residential.to_excel('residential.xlsx') 
# files.download('residential.xlsx')

# %%
col_dict = {'name': 'Nume',
            'address': 'Adresa',
            'developer': 'Dezvoltator',
            'city': 'Oras',
            'date': 'Data',
            'href2': 'Href',
            'main_price_from': 'Pret minim',
            'mean_price': 'Pret mediu',
            'total_space': 'Spatiu total m2',
            'website': 'Website'}   ## key→old name, value→new name

table_all_char_sketpri_meanpr_tspace_w.columns = [col_dict.get(x, x) for x in table_all_char_sketpri_meanpr_tspace_w.columns]
table_all_char_sketpri_meanpr_tspace_w
# Out:
#                            Nume  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 479           Proiect Burebista
# 480          Proiect Anton Pann
# 481                       Wings
# 482          Brancusi Residence
# 483      City Comfort Residence
#
#                                                 Adresa  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 479  str. Burebista, 8, zona Parcul Feroviarilor, C...
# 480  str. Anton Pann, 10-16, zona Mărăști, Cluj-Napoca
# 481               str. Frunzisului, 88A, Cluj - Napoca
# 482  str. Constantin Brâncuși, 128, zona Andrei Mur...
# 483           str. Razoare, zona Floresti, Cluj-Napoca
#
#                    Dezvoltator       Oras      data  \
# 0                       Cordia  Bucuresti  02/03/21
# 1    Metropolitan Developments  Bucuresti  02/03/21
# 2              Ideal Construct  Bucuresti  02/03/21
# 3                       Natrom  Bucuresti  02/03/21
# 4         Living Spaces Design  Bucuresti  02/03/21
# ..                         ...        ...       ...
# 479          SC SDC Imobiliare       Cluj  02/03/21
# 480          SC SDC Imobiliare       Cluj  02/03/21
# 481              Studium Green       Cluj  02/03/21
# 482         Brancusi Residence       Cluj  02/03/21
# 483     City Comfort Residence       Cluj  02/03/21
#
#                                     Href                        Pret minim  \
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 872 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 479        /proiect-burebista-clujnapoca  prețul pentru un m2 se clarifică
# 480       /proiect-anton-pann-clujnapoca  prețul pentru un m2 se clarifică
# 481                   /wings-cluj-napoca             de la 1 350 € +TVA/m2
# 482       /brancusi-residence-clujnapoca             de la 1 751 € +TVA/m2
# 483   /city-comfort-residence-clujnapoca             de la 1 073 € +TVA/m2
#
#     Facilităţi Lift Mijloace de transport  ... 4 camere CaseCasa Tip A1  \
# 0          NaN  NaN                   NaN  ...      NaN             NaN
# 1          NaN  NaN                   NaN  ...      NaN             NaN
# 2          NaN  NaN                   NaN  ...      NaN             NaN
# 3          NaN  NaN                   NaN  ...      NaN             NaN
# 4          NaN  NaN                   NaN  ...      NaN             NaN
# ..         ...  ...                   ...  ...      ...             ...
# 479        NaN  NaN                   NaN  ...      NaN             NaN
# 480        NaN  NaN                   NaN  ...      NaN             NaN
# 481        NaN  NaN                   NaN  ...      NaN             NaN
# 482        NaN  NaN                   NaN  ...      NaN             NaN
# 483        NaN  NaN                   NaN  ...      NaN             NaN
#
#     Duplex-uri Garsoniere Penthouse-uri Studiouri Vile Pret mediu  \
# 0          NaN        NaN           NaN       NaN  NaN        nan
# 1          NaN        NaN           NaN       NaN  NaN        nan
# 2          NaN        NaN           NaN       NaN  NaN        nan
# 3          NaN        NaN           NaN       NaN  NaN        nan
# 4          NaN        NaN           NaN       NaN  NaN        nan
# ..         ...        ...           ...       ...  ...        ...
# 479        NaN        NaN           NaN       NaN  NaN        nan
# 480        NaN        NaN           NaN       NaN  NaN        nan
# 481        NaN        NaN           NaN       NaN  NaN        nan
# 482        NaN        NaN           NaN       NaN  NaN        nan
# 483        NaN        NaN           NaN       NaN  NaN        nan
#
#     Spatiu total m2 Website
# 0               nan     NaN
# 1               nan     NaN
# 2               nan     NaN
# 3               nan     NaN
# 4               nan     NaN
# ..              ...     ...
# 479             nan     NaN
# 480             nan     NaN
# 481             nan     NaN
# 482             nan     NaN
# 483             nan     NaN
#
# [484 rows x 33 columns]

# %%
pd.options.display.float_format = '{:,.2f}'.format
cols_to_order = ['Nume', 'Adresa', 'Dezvoltator', 'Oras', 'Website', 'Href', 'Pret minim', 'Pret mediu', 'Spatiu total m2']
new_columns = cols_to_order + (table_all_char_sketpri_meanpr_tspace_w.columns.drop(cols_to_order).tolist())
table_all_char_sketpri_meanpr_tspace_w = table_all_char_sketpri_meanpr_tspace_w[new_columns]
table_all_char_sketpri_meanpr_tspace_w
# Out:
#                            Nume  \
# 0                   Parcului 20
# 1          Metropolitan Berceni
# 2           MK Residence Pipera
# 3               Natrom Pipera 1
# 4    LSD - Living Spaces Design
# ..                          ...
# 479           Proiect Burebista
# 480          Proiect Anton Pann
# 481                       Wings
# 482          Brancusi Residence
# 483      City Comfort Residence
#
#                                                 Adresa  \
# 0    str. Parcului, 20, zona Piața Presei Libere, s...
# 1    șos. Berceni, 94, zona Apărătorii Patriei, sec...
# 2               str. Matei Millo, 94, Voluntari, Ilfov
# 3     bd. Pipera, 1D-2, zona  Pipera, Voluntari, Ilfov
# 4         Balotești, str. Paris, zona Balotești, Ilfov
# ..                                                 ...
# 479  str. Burebista, 8, zona Parcul Feroviarilor, C...
# 480  str. Anton Pann, 10-16, zona Mărăști, Cluj-Napoca
# 481               str. Frunzisului, 88A, Cluj - Napoca
# 482  str. Constantin Brâncuși, 128, zona Andrei Mur...
# 483           str. Razoare, zona Floresti, Cluj-Napoca
#
#                    Dezvoltator       Oras Website  \
# 0                       Cordia  Bucuresti     NaN
# 1    Metropolitan Developments  Bucuresti     NaN
# 2              Ideal Construct  Bucuresti     NaN
# 3                       Natrom  Bucuresti     NaN
# 4         Living Spaces Design  Bucuresti     NaN
# ..                         ...        ...     ...
# 479          SC SDC Imobiliare       Cluj     NaN
# 480          SC SDC Imobiliare       Cluj     NaN
# 481              Studium Green       Cluj     NaN
# 482         Brancusi Residence       Cluj     NaN
# 483     City Comfort Residence       Cluj     NaN
#
#                                     Href                        Pret minim  \
# 0                 /parcului-20-bucuresti             de la 1 034 € +TVA/m2
# 1        /metropolitan-berceni-bucuresti                  de la 1 133 €/m2
# 2         /mk-residence-pipera-bucuresti             de la 1 087 € +TVA/m2
# 3             /natrom-pipera-1-bucuresti               de la 872 € +TVA/m2
# 4    /lsd-living-spaces-design-bucuresti  prețul pentru un m2 se clarifică
# ..                                   ...                               ...
# 479        /proiect-burebista-clujnapoca  prețul pentru un m2 se clarifică
# 480       /proiect-anton-pann-clujnapoca  prețul pentru un m2 se clarifică
# 481                   /wings-cluj-napoca             de la 1 350 € +TVA/m2
# 482       /brancusi-residence-clujnapoca             de la 1 751 € +TVA/m2
# 483   /city-comfort-residence-clujnapoca             de la 1 073 € +TVA/m2
#
#      Pret mediu  Spatiu total m2      data  ... 2 camere 3 camere  \
# 0           nan              nan  02/03/21  ...      NaN      NaN
# 1           nan              nan  02/03/21  ...      NaN      NaN
# 2           nan              nan  02/03/21  ...      NaN      NaN
# 3           nan              nan  02/03/21  ...      NaN      NaN
# 4           nan              nan  02/03/21  ...      NaN      NaN
# ..          ...              ...       ...  ...      ...      ...
# 479         nan              nan  02/03/21  ...      NaN      NaN
# 480         nan              nan  02/03/21  ...      NaN      NaN
# 481         nan              nan  02/03/21  ...      NaN      NaN
# 482         nan              nan  02/03/21  ...      NaN      NaN
# 483         nan              nan  02/03/21  ...      NaN      NaN
#
#     3 camereduplex 4 camere CaseCasa Tip A1 Duplex-uri Garsoniere  \
# 0              NaN      NaN             NaN        NaN        NaN
# 1              NaN      NaN             NaN        NaN        NaN
# 2              NaN      NaN             NaN        NaN        NaN
# 3              NaN      NaN             NaN        NaN        NaN
# 4              NaN      NaN             NaN        NaN        NaN
# ..             ...      ...             ...        ...        ...
# 479            NaN      NaN             NaN        NaN        NaN
# 480            NaN      NaN             NaN        NaN        NaN
# 481            NaN      NaN             NaN        NaN        NaN
# 482            NaN      NaN             NaN        NaN        NaN
# 483            NaN      NaN             NaN        NaN        NaN
#
#     Penthouse-uri Studiouri Vile
# 0             NaN       NaN  NaN
# 1             NaN       NaN  NaN
# 2             NaN       NaN  NaN
# 3             NaN       NaN  NaN
# 4             NaN       NaN  NaN
# ..            ...       ...  ...
# 479           NaN       NaN  NaN
# 480           NaN       NaN  NaN
# 481           NaN       NaN  NaN
# 482           NaN       NaN  NaN
# 483           NaN       NaN  NaN
#
# [484 rows x 33 columns]

# %%
# Export
table_all_char_sketpri_meanpr.to_excel("/Users/robert.radoslav/desktop/residential_final.xlsx", sheet_name="All cities")

# Colab export alternative
# from google.colab import files
# residential.to_excel('residential.xlsx') 
# files.download('residential.xlsx')
